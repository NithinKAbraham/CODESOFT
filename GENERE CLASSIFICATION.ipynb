# %% [markdown]
# # MOVIE GENURE CLASSIFICATION

# %% [markdown]
# #### ==========================================

# %% [markdown]
# #### WHAT IS A MOVIE GENURE   ?

# %% [markdown]
# A movie genre is a category that classifies films based on their thematic elements, narrative style, and tone.
#
# Common genres include action, drama, comedy, horror, science fiction, and romance. Each genre has distinct
#
# characteristics that define the type of story and emotions portrayed in the film.

# %% [markdown]
# #### WHAT ARE THE COMMON TYPE  OF MOVIE GENURE ?

# %% [raw]
# 1. ACTION :
#
#           Focused on intense physical activities, often involving feats of daring and excitement.

# %% [raw]
# 2. DRAMA  :
#
#           Emphasizes character development and interpersonal conflicts, often exploring emotional themes.

# %% [raw]
# 3. Comedy:
#
#           Intended to amuse and entertain, typically characterized by humor and lighthearted storytelling.

# %% [raw]
# 4 .Horror:
#
#           Designed to evoke fear and suspense, often featuring supernatural or frightening elements.

# %% [raw]
# 5. Science Fiction:
#
#           Explores speculative concepts often related to futuristic technology, space, and otherworldly scenarios.

# %% [raw]
# 6. Romance:
#
#           Centered around romantic relationships and the emotional connections between characters.

# %% [raw]
# 7. Thriller:
#
#           Builds tension and suspense, often involving crime, mystery, or psychological twists.

# %% [raw]
# 8. Fantasy:
#
#           Features magical or supernatural elements, often set in imaginary worlds.

# %% [raw]
# 9. Adventure:
#
#           Involves characters embarking on a journey or quest, often with elements of excitement and discovery.

# %% [raw]
# 10. Mystery:
#
#            Focuses on solving a puzzle or uncovering hidden information, often involving crime or detective work.

# %% [markdown]
# # ==================================================

# %% [markdown]
# ##### IMPORT PAKAGES

# %%
import numpy as np

import pandas as pd

import seaborn as sns

import matplotlib.pyplot as plt

# %%
import nltk

from nltk import word_tokenize

import string

import re

# %%
#MODEl 

from sklearn.linear_model import LogisticRegression

from sklearn.tree import DecisionTreeClassifier

from sklearn.ensemble import RandomForestClassifier

# %% [markdown]
# ##### LOAD THE DATASET

# %%
df=pd.read_csv("F:/CODE SOFT/Genre Classification Dataset/train_data.txt",sep='\t',header=None,names=["TEXT"])

# %%
df
# Out:
#                                                     TEXT
# 0      1 ::: Oscar et la dame rose (2009) ::: drama :...
# 1      2 ::: Cupid (1997) ::: thriller ::: A brother ...
# 2      3 ::: Young, Wild and Wonderful (1980) ::: adu...
# 3      4 ::: The Secret Sin (1915) ::: drama ::: To h...
# 4      5 ::: The Unrecovered (2007) ::: drama ::: The...
# ...                                                  ...
# 54209  54210 ::: "Bonino" (1953) ::: comedy ::: This ...
# 54210  54211 ::: Dead Girls Don't Cry (????) ::: horr...
# 54211  54212 ::: Ronald Goedemondt: Ze bestaan echt (...
# 54212  54213 ::: Make Your Own Bed (1944) ::: comedy ...
# 54213  54214 ::: Nature's Fury: Storm of the Century ...
#
# [54214 rows x 1 columns]

# %%
df[['No.','Title','Genre','Description']]=df['TEXT'].str.split(":::",expand=True)

# %%
df=df.drop(["TEXT","No."],axis=1)

# %%
df
# Out:
#                                               Title          Genre
# 0                     Oscar et la dame rose (2009)          drama   \
# 1                                     Cupid (1997)       thriller
# 2                 Young, Wild and Wonderful (1980)          adult
# 3                            The Secret Sin (1915)          drama
# 4                           The Unrecovered (2007)          drama
# ...                                             ...            ...
# 54209                              "Bonino" (1953)         comedy
# 54210                  Dead Girls Don't Cry (????)         horror
# 54211    Ronald Goedemondt: Ze bestaan echt (2008)    documentary
# 54212                     Make Your Own Bed (1944)         comedy
# 54213   Nature's Fury: Storm of the Century (2006)        history
#
#                                              Description
# 0       Listening in to a conversation between his do...
# 1       A brother and sister with a past incestuous r...
# 2       As the bus empties the students for their fie...
# 3       To help their unemployed father make ends mee...
# 4       The film's title refers not only to the un-re...
# ...                                                  ...
# 54209   This short-lived NBC live sitcom centered on ...
# 54210   The NEXT Generation of EXPLOITATION. The sist...
# 54211   Ze bestaan echt, is a stand-up comedy about g...
# 54212   Walter and Vivian live in the country and hav...
# 54213   On Labor Day Weekend, 1935, the most intense ...
#
# [54214 rows x 3 columns]

# %%
df.head()
# Out:
#                                 Title       Genre
# 0       Oscar et la dame rose (2009)       drama   \
# 1                       Cupid (1997)    thriller
# 2   Young, Wild and Wonderful (1980)       adult
# 3              The Secret Sin (1915)       drama
# 4             The Unrecovered (2007)       drama
#
#                                          Description
# 0   Listening in to a conversation between his do...
# 1   A brother and sister with a past incestuous r...
# 2   As the bus empties the students for their fie...
# 3   To help their unemployed father make ends mee...
# 4   The film's title refers not only to the un-re...

# %%
df.tail()
# Out:
#                                               Title          Genre
# 54209                              "Bonino" (1953)         comedy   \
# 54210                  Dead Girls Don't Cry (????)         horror
# 54211    Ronald Goedemondt: Ze bestaan echt (2008)    documentary
# 54212                     Make Your Own Bed (1944)         comedy
# 54213   Nature's Fury: Storm of the Century (2006)        history
#
#                                              Description
# 54209   This short-lived NBC live sitcom centered on ...
# 54210   The NEXT Generation of EXPLOITATION. The sist...
# 54211   Ze bestaan echt, is a stand-up comedy about g...
# 54212   Walter and Vivian live in the country and hav...
# 54213   On Labor Day Weekend, 1935, the most intense ...

# %%
df.sample(10)
# Out:
#                                           Title          Genre
# 50498                          Me Me Me (2011)        musical   \
# 3878          Transworld Skate & Create (2010)    documentary
# 26698        Apollo 11, un pas en fals? (2010)          short
# 24212                   The Intruders (2015/I)       thriller
# 20221   Art on Film, Program 1: Balance (1992)    documentary
# 18579              La Pica sul Pacifico (1959)         comedy
# 5253                   Hello, Annapolis (1942)         comedy
# 10514                     Préméditation (1960)          drama
# 9237                            Atoll K (1951)         comedy
# 43103                         "Erwtje!" (2001)          drama
#
#                                              Description
# 50498   Jane Fellowes is a work experience girl on Br...
# 3878    For the first time ever, a TransWorld TV show...
# 26698   This mockumentary shows us what would have ha...
# 24212   The disturbed twenty year-old Rose Halshford ...
# 20221   The Program for Art on Film was a joint ventu...
# 18579   Adelaide riceve in ereditŕ dal marito Beniami...
# 5253    Bill Arden and Paul Herbert sign up at the ti...
# 10514   Bernard Sommet has killed his wife and her lo...
# 9237    Heading for a newly inherited island, the boy...
# 43103   Six episodes in which ERWTJE constantly seems...

# %%
df.shape
# Out:
# (54214, 3)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54214 entries, 0 to 54213
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Title        54214 non-null  object
#  1   Genre        54214 non-null  object
#  2   Description  54214 non-null  object
# dtypes: object(3)
# memory usage: 1.2+ MB

# %%
df.describe().T
# Out:
#              count unique                                                top
# Title        54214  54214                      Oscar et la dame rose (2009)   \
# Genre        54214     27                                             drama
# Description  54214  54086   Grammy - music award of the American academy ...
#
#               freq
# Title            1
# Genre        13613
# Description     12

# %%
df.isna().sum()
# Out:
# Title          0
# Genre          0
# Description    0
# dtype: int64

# %%
df.dtypes
# Out:
# Title          object
# Genre          object
# Description    object
# dtype: object

# %%
df["Genre"].value_counts()
# Out:
# Genre
#  drama           13613
#  documentary     13096
#  comedy           7447
#  short            5073
#  horror           2204
#  thriller         1591
#  action           1315
#  western          1032
#  reality-tv        884
#  family            784
#  adventure         775
#  music             731
#  romance           672
#  sci-fi            647
#  adult             590
#  crime             505
#  animation         498
#  sport             432
#  talk-show         391
#  fantasy           323
#  mystery           319
#  musical           277
#  biography         265
#  history           243
#  game-show         194
#  news              181
#  war               132
# Name: count, dtype: int64

# %%
Genre_count=df['Genre'].value_counts()

# %%
valid_Genre=Genre_count[Genre_count>=900].index
df=df[df['Genre'].isin(valid_Genre)]
df
# Out:
#                                              Title          Genre
# 0                    Oscar et la dame rose (2009)          drama   \
# 1                                    Cupid (1997)       thriller
# 3                           The Secret Sin (1915)          drama
# 4                          The Unrecovered (2007)          drama
# 5                          Quality Control (2011)    documentary
# ...                                            ...            ...
# 54207                              Kaçamak (1988)          drama
# 54209                             "Bonino" (1953)         comedy
# 54210                 Dead Girls Don't Cry (????)         horror
# 54211   Ronald Goedemondt: Ze bestaan echt (2008)    documentary
# 54212                    Make Your Own Bed (1944)         comedy
#
#                                              Description
# 0       Listening in to a conversation between his do...
# 1       A brother and sister with a past incestuous r...
# 3       To help their unemployed father make ends mee...
# 4       The film's title refers not only to the un-re...
# 5       Quality Control consists of a series of 16mm ...
# ...                                                  ...
# 54207   A man and woman meet during the identificatio...
# 54209   This short-lived NBC live sitcom centered on ...
# 54210   The NEXT Generation of EXPLOITATION. The sist...
# 54211   Ze bestaan echt, is a stand-up comedy about g...
# 54212   Walter and Vivian live in the country and hav...
#
# [45371 rows x 3 columns]

# %%
plt.figure(figsize=(17,6))

sns.countplot(df,x="Genre")

plt.show()

# %% [markdown]
# ##### NLP - TECHNIQUES

# %%
Review=df['Description']
Review
# Out:
# 0         Listening in to a conversation between his do...
# 1         A brother and sister with a past incestuous r...
# 3         To help their unemployed father make ends mee...
# 4         The film's title refers not only to the un-re...
# 5         Quality Control consists of a series of 16mm ...
#                                ...
# 54207     A man and woman meet during the identificatio...
# 54209     This short-lived NBC live sitcom centered on ...
# 54210     The NEXT Generation of EXPLOITATION. The sist...
# 54211     Ze bestaan echt, is a stand-up comedy about g...
# 54212     Walter and Vivian live in the country and hav...
# Name: Description, Length: 45371, dtype: object

# %%
tokens=[]

for i in Review:
    eachword=word_tokenize(i)
    tokens.extend(eachword)

tokens
# Out:
# ['Listening',
#  'in',
#  'to',
#  'a',
#  'conversation',
#  'between',
#  'his',
#  'doctor',
#  'and',
#  'parents',
#  ',',
#  '10-year-old',
#  'Oscar',
#  'learns',
#  'what',
#  'nobody',
#  'has',
#  'the',
#  'courage',
#  'to',
#  'tell',
#  'him',
#  '.',
#  'He',
#  'only',
#  'has',
#  'a',
#  'few',
#  'weeks',
#  'to',
#  'live',
#  '.',
#  'Furious',
#  ',',
#  'he',
#  'refuses',
#  'to',
#  'speak',
#  'to',
#  'anyone',
#  'except',
#  'straight-talking',
#  'Rose',
#  ',',
#  'the',
#  'lady',
#  'in',
#  'pink',
#  'he',
#  'meets',
#  'on',
#  'the',
#  'hospital',
#  'stairs',
#  '.',
#  'As',
#  'Christmas',
#  'approaches',
#  ',',
#  'Rose',
#  'uses',
#  'her',
#  'fantastical',
#  'experiences',
#  'as',
#  'a',
#  'professional',
#  'wrestler',
#  ',',
#  'her',
#  'imagination',
#  ',',
#  'wit',
#  'and',
#  'charm',
#  'to',
#  'allow',
#  'Oscar',
#  'to',
#  'live',
#  'life',
#  'and',
#  'love',
#  'to',
#  'the',
#  'full',
#  ',',
#  'in',
#  'the',
#  'company',
#  'of',
#  'his',
#  'friends',
#  'Pop',
#  'Corn',
#  ',',
#  'Einstein',
#  ',',
#  'Bacon',
#  'and',
#  'childhood',
#  'sweetheart',
#  'Peggy',
#  'Blue',
#  '.',
#  'A',
#  'brother',
#  'and',
#  'sister',
#  'with',
#  'a',
#  'past',
#  'incestuous',
#  'relationship',
#  'have',
#  'a',
#  'current',
#  'murderous',
#  'relationship',
#  '.',
#  'He',
#  'murders',
#  'the',
#  'women',
#  'who',
#  'reject',
#  'him',
#  'and',
#  'she',
#  'murders',
#  'the',
#  'women',
#  'who',
#  'get',
#  'too',
#  'close',
#  'to',
#  'him',
#  '.',
#  'To',
#  'help',
#  'their',
#  'unemployed',
#  'father',
#  'make',
#  'ends',
#  'meet',
#  ',',
#  'Edith',
#  'and',
#  'her',
#  'twin',
#  'sister',
#  'Grace',
#  'work',
#  'as',
#  'seamstresses',
#  '.',
#  'An',
#  'invalid',
#  ',',
#  'Grace',
#  'falls',
#  'prey',
#  'to',
#  'the',
#  'temptations',
#  'of',
#  'Chinatown',
#  'opium',
#  'and',
#  'becomes',
#  'an',
#  'addict',
#  ',',
#  'a',
#  'condition',
#  'worsened',
#  'by',
#  'a',
#  'misguided',
#  'physician',
#  'who',
#  'prescribes',
#  'morphine',
#  'to',
#  'ease',
#  'her',
#  'pain',
#  '.',
#  'When',
#  'their',
#  'father',
#  'strikes',
#  'oil',
#  ',',
#  'the',
#  'family',
#  'enjoys',
#  'a',
#  'new',
#  'prosperity',
#  'and',
#  'the',
#  'sisters',
#  'meet',
#  'the',
#  'eligible',
#  'Jack',
#  'Herron',
#  ',',
#  'a',
#  'fellow',
#  'oil',
#  'prospector',
#  '.',
#  'To',
#  'Grace',
#  "'s",
#  'shock',
#  ',',
#  'Jack',
#  'falls',
#  'in',
#  'love',
#  'with',
#  'Edith',
#  'and',
#  'in',
#  'her',
#  'jealousy',
#  ',',
#  'Grace',
#  'tells',
#  'Jack',
#  'that',
#  'Edith',
#  ',',
#  'not',
#  'she',
#  ',',
#  'has',
#  'a',
#  'drug',
#  'problem',
#  '.',
#  'Hinting',
#  'that',
#  'her',
#  'sister',
#  'will',
#  'soon',
#  'need',
#  'more',
#  'morphine',
#  ',',
#  'Grace',
#  'arranges',
#  'for',
#  'a',
#  'dinner',
#  'in',
#  'Chinatown',
#  'with',
#  'the',
#  'couple',
#  '.',
#  'While',
#  'her',
#  'sister',
#  'and',
#  'Jack',
#  'dance',
#  ',',
#  'Grace',
#  'slips',
#  'away',
#  'to',
#  'an',
#  'opium',
#  'den',
#  '.',
#  'Edith',
#  'follows',
#  'her',
#  ',',
#  'but',
#  'ends',
#  'up',
#  'in',
#  'the',
#  'wrong',
#  'den',
#  'and',
#  'is',
#  'arrested',
#  'in',
#  'an',
#  'ensuing',
#  'drug',
#  'raid',
#  '.',
#  'After',
#  'he',
#  'bails',
#  'her',
#  'out',
#  'of',
#  'jail',
#  ',',
#  'Edith',
#  'takes',
#  'an',
#  'angry',
#  'Jack',
#  'to',
#  'search',
#  'for',
#  'Grace',
#  'and',
#  'stumbles',
#  'across',
#  'her',
#  'half-conscious',
#  'body',
#  'lying',
#  'in',
#  'the',
#  'street',
#  '.',
#  'The',
#  'truth',
#  'about',
#  'the',
#  'sisters',
#  'is',
#  'revealed',
#  ',',
#  'and',
#  'after',
#  'sending',
#  'Grace',
#  'to',
#  'a',
#  'sanitarium',
#  'in',
#  'the',
#  'country',
#  ',',
#  'Jack',
#  'and',
#  'Edith',
#  'are',
#  'married',
#  '.',
#  'The',
#  'film',
#  "'s",
#  'title',
#  'refers',
#  'not',
#  'only',
#  'to',
#  'the',
#  'un-recovered',
#  'bodies',
#  'at',
#  'ground',
#  'zero',
#  ',',
#  'but',
#  'also',
#  'to',
#  'the',
#  'state',
#  'of',
#  'the',
#  'nation',
#  'at',
#  'large',
#  '.',
#  'Set',
#  'in',
#  'the',
#  'hallucinatory',
#  'period',
#  'of',
#  'time',
#  'between',
#  'September',
#  '11',
#  'and',
#  'Halloween',
#  'of',
#  '2001',
#  ',',
#  'The',
#  'Unrecovered',
#  'examines',
#  'the',
#  'effect',
#  'of',
#  'terror',
#  'on',
#  'the',
#  'average',
#  'mind',
#  ',',
#  'the',
#  'way',
#  'a',
#  'state',
#  'of',
#  'heightened',
#  'anxiety',
#  'and/or',
#  'alertness',
#  'can',
#  'cause',
#  'the',
#  'average',
#  'person',
#  'to',
#  'make',
#  'the',
#  'sort',
#  'of',
#  'imaginative',
#  'connections',
#  'that',
#  'are',
#  'normally',
#  'made',
#  'only',
#  'by',
#  'artists',
#  'and',
#  'conspiracy',
#  'theorists-both',
#  'of',
#  'whom',
#  'figure',
#  'prominently',
#  'in',
#  'this',
#  'film',
#  '.',
#  'The',
#  'Unrecovered',
#  'explores',
#  'the',
#  'way',
#  'in',
#  'which',
#  'irony',
#  ',',
#  'empathy',
#  ',',
#  'and',
#  'paranoia',
#  'relate',
#  'to',
#  'one',
#  'another',
#  'in',
#  'the',
#  'wake',
#  'of',
#  '9/11',
#  '.',
#  'Quality',
#  'Control',
#  'consists',
#  'of',
#  'a',
#  'series',
#  'of',
#  '16mm',
#  'single',
#  'take',
#  'shots',
#  'filmed',
#  'in',
#  'the',
#  'summer',
#  'of',
#  '2010',
#  ',',
#  'over',
#  'a',
#  'two',
#  'day',
#  'period',
#  ',',
#  'in',
#  'a',
#  'dry',
#  'cleaners',
#  'facility',
#  'in',
#  'Pritchard',
#  ',',
#  'Alabama',
#  ',',
#  'near',
#  'Mobile',
#  ',',
#  'Quality',
#  'Control',
#  'exhibits',
#  'the',
#  'acts',
#  'as',
#  'well',
#  'the',
#  'conditions',
#  'around',
#  'labor',
#  'and',
#  'showcases',
#  ',',
#  'in',
#  'Everson',
#  "'s",
#  'words',
#  '``',
#  'the',
#  'fine',
#  'folks',
#  'of',
#  'Alabama',
#  'producing',
#  'a',
#  'superior',
#  'product',
#  '.',
#  "''",
#  'It',
#  'is',
#  'similar',
#  'stylistically',
#  ',',
#  'in',
#  'form',
#  'and',
#  'rhythm',
#  ',',
#  'to',
#  'certain',
#  'scenarios',
#  'in',
#  'Everson',
#  "'s",
#  'award-winning',
#  'and',
#  'critically',
#  'acclaimed',
#  'previous',
#  'films',
#  ',',
#  'including',
#  'Erie',
#  '(',
#  'IFFR',
#  '2010',
#  ')',
#  'and',
#  'in',
#  'thematic',
#  'concerns',
#  'to',
#  'several',
#  'other',
#  'short',
#  'form',
#  'works',
#  'which',
#  'follow',
#  'the',
#  'daily',
#  ',',
#  'quotidian',
#  'tasks',
#  'of',
#  'workers',
#  'in',
#  'rest',
#  'and',
#  'in',
#  'motion',
#  ',',
#  'and',
#  'is',
#  'an',
#  'oblique',
#  'sequel',
#  ',',
#  'ten',
#  'years',
#  'hence',
#  ',',
#  'to',
#  'Everson',
#  "'s",
#  'Creative',
#  'Capital',
#  'granted',
#  'project',
#  'A',
#  'Week',
#  'in',
#  'the',
#  'Hole',
#  '(',
#  '2001',
#  ')',
#  ',',
#  'which',
#  'focused',
#  'on',
#  'an',
#  'employee',
#  "'s",
#  'adjustment',
#  'to',
#  'materials',
#  ',',
#  'time',
#  ',',
#  'space',
#  'and',
#  'personnel',
#  '.',
#  'Quality',
#  'Control',
#  'consists',
#  'of',
#  'a',
#  'series',
#  'of',
#  '16mm',
#  'single',
#  'take',
#  'shots',
#  ',',
#  'filmed',
#  'over',
#  'a',
#  'two',
#  'day',
#  'period',
#  'in',
#  'the',
#  'summer',
#  'of',
#  '2010',
#  ',',
#  'in',
#  'a',
#  'dry',
#  'cleaners',
#  'facility',
#  'in',
#  'Pritchard',
#  ',',
#  'Alabama',
#  ',',
#  'near',
#  'Mobile',
#  '.',
#  'Quality',
#  'Control',
#  'exhibits',
#  'the',
#  'acts',
#  'as',
#  'well',
#  'the',
#  'conditions',
#  'around',
#  'labor',
#  '.',
#  'It',
#  'is',
#  'similar',
#  'stylistically',
#  ',',
#  'in',
#  'form',
#  'and',
#  'rhythm',
#  ',',
#  'to',
#  'certain',
#  'scenarios',
#  'in',
#  'Everson',
#  "'s",
#  'award-winning',
#  'and',
#  'critically',
#  'acclaimed',
#  'previous',
#  'films',
#  ',',
#  'including',
#  'Erie',
#  '(',
#  'IFFR',
#  '2010',
#  ')',
#  'and',
#  'in',
#  'thematic',
#  'concerns',
#  'to',
#  'several',
#  'other',
#  'short',
#  'form',
#  'works',
#  'which',
#  'follow',
#  'the',
#  'daily',
#  ',',
#  'quotidian',
#  'tasks',
#  'of',
#  'workers',
#  'in',
#  'rest',
#  'and',
#  'in',
#  'motion',
#  ',',
#  'including',
#  'the',
#  'factory',
#  'routine',
#  'captured',
#  'in',
#  'the',
#  'short',
#  'film',
#  'A',
#  'Week',
#  'in',
#  'the',
#  'Hole',
#  '(',
#  '2001',
#  ')',
#  ',',
#  'which',
#  'focused',
#  'on',
#  'an',
#  'employee',
#  "'s",
#  'adjustment',
#  'to',
#  'materials',
#  ',',
#  'time',
#  ',',
#  'space',
#  'and',
#  'personnel',
#  '.',
#  'Principal',
#  'cast',
#  'includes',
#  'Shay',
#  'Wright',
#  'and',
#  'Annette',
#  'Speight',
#  '.',
#  'In',
#  'tough',
#  'economic',
#  'times',
#  'Max',
#  'and',
#  'Joey',
#  'have',
#  'all',
#  'but',
#  'run',
#  'out',
#  'of',
#  'ideas',
#  'until',
#  ',',
#  'they',
#  'discover',
#  'that',
#  'senior',
#  'housing',
#  'is',
#  'cheap',
#  '.',
#  'Not',
#  'only',
#  'that',
#  'but',
#  'Max',
#  "'s",
#  'aunt',
#  'just',
#  'kicked',
#  'the',
#  'bucket',
#  'and',
#  'no',
#  'one',
#  'knows',
#  'yet',
#  '.',
#  'In',
#  'a',
#  'hilarious',
#  'series',
#  'that',
#  'always',
#  'keeps',
#  'you',
#  'on',
#  'your',
#  'toes',
#  ',',
#  'the',
#  'two',
#  'friends',
#  'take',
#  'us',
#  'on',
#  'a',
#  'cross-dressing',
#  ',',
#  'desperate',
#  'and',
#  'endearing',
#  'ride',
#  'through',
#  'being',
#  'broke',
#  '.',
#  'Four',
#  'high',
#  'school',
#  'students',
#  'embark',
#  'on',
#  'a',
#  'terrifying',
#  'journey',
#  'through',
#  'ShadowView',
#  'Manor',
#  '2',
#  'years',
#  'after',
#  'a',
#  'horrifying',
#  'séance',
#  'gone',
#  'wrong',
#  '.',
#  'Intern',
#  'Raven',
#  ',',
#  'decides',
#  'to',
#  'reconnect',
#  'with',
#  'her',
#  'elementary',
#  'school',
#  'friends',
#  'Kota',
#  ',',
#  'William',
#  ',',
#  'and',
#  'Jessica',
#  'by',
#  'bringing',
#  'them',
#  'to',
#  'her',
#  'new',
#  'workplace',
#  ',',
#  'ShadowView',
#  'Manor',
#  'for',
#  'a',
#  'bit',
#  'of',
#  'paranormal',
#  'investigating',
#  '.',
#  'Hearing',
#  'more',
#  'forbidden',
#  'secrets',
#  'from',
#  'the',
#  'night',
#  'janitor',
#  'sends',
#  'them',
#  'into',
#  'a',
#  'dark',
#  'descending',
#  'spiral',
#  'of',
#  'terror',
#  '.',
#  'Tom',
#  'Beacham',
#  'explores',
#  'Ghana',
#  'with',
#  'Director',
#  'of',
#  'Photography',
#  'Alex',
#  'Holberton',
#  ',',
#  'in',
#  'search',
#  'of',
#  'Spirits',
#  '.',
#  'The',
#  'film',
#  'looks',
#  'at',
#  'the',
#  'overlap',
#  'between',
#  'the',
#  'spirit',
#  'world',
#  'and',
#  'the',
#  'physical',
#  'world',
#  ',',
#  'voodoo',
#  ',',
#  'witchcraft',
#  ',',
#  'the',
#  'power',
#  'of',
#  'the',
#  'Holy',
#  'Spirit',
#  'and',
#  'magic',
#  '.',
#  'They',
#  'meet',
#  'with',
#  'royal',
#  'family',
#  'members',
#  ',',
#  'magicians',
#  'and',
#  'voodoo',
#  'priests',
#  'as',
#  'well',
#  'as',
#  'getting',
#  'rare',
#  'footage',
#  'of',
#  'a',
#  'full',
#  'Voodoo',
#  'Ceremony',
#  '.',
#  'Danny',
#  ',',
#  'dying',
#  'of',
#  'Aids',
#  ',',
#  'returns',
#  'home',
#  'for',
#  'his',
#  'last',
#  ...]

# %%
lower=[i.lower() for i in tokens]

lower
# Out:
# ['listening',
#  'in',
#  'to',
#  'a',
#  'conversation',
#  'between',
#  'his',
#  'doctor',
#  'and',
#  'parents',
#  ',',
#  '10-year-old',
#  'oscar',
#  'learns',
#  'what',
#  'nobody',
#  'has',
#  'the',
#  'courage',
#  'to',
#  'tell',
#  'him',
#  '.',
#  'he',
#  'only',
#  'has',
#  'a',
#  'few',
#  'weeks',
#  'to',
#  'live',
#  '.',
#  'furious',
#  ',',
#  'he',
#  'refuses',
#  'to',
#  'speak',
#  'to',
#  'anyone',
#  'except',
#  'straight-talking',
#  'rose',
#  ',',
#  'the',
#  'lady',
#  'in',
#  'pink',
#  'he',
#  'meets',
#  'on',
#  'the',
#  'hospital',
#  'stairs',
#  '.',
#  'as',
#  'christmas',
#  'approaches',
#  ',',
#  'rose',
#  'uses',
#  'her',
#  'fantastical',
#  'experiences',
#  'as',
#  'a',
#  'professional',
#  'wrestler',
#  ',',
#  'her',
#  'imagination',
#  ',',
#  'wit',
#  'and',
#  'charm',
#  'to',
#  'allow',
#  'oscar',
#  'to',
#  'live',
#  'life',
#  'and',
#  'love',
#  'to',
#  'the',
#  'full',
#  ',',
#  'in',
#  'the',
#  'company',
#  'of',
#  'his',
#  'friends',
#  'pop',
#  'corn',
#  ',',
#  'einstein',
#  ',',
#  'bacon',
#  'and',
#  'childhood',
#  'sweetheart',
#  'peggy',
#  'blue',
#  '.',
#  'a',
#  'brother',
#  'and',
#  'sister',
#  'with',
#  'a',
#  'past',
#  'incestuous',
#  'relationship',
#  'have',
#  'a',
#  'current',
#  'murderous',
#  'relationship',
#  '.',
#  'he',
#  'murders',
#  'the',
#  'women',
#  'who',
#  'reject',
#  'him',
#  'and',
#  'she',
#  'murders',
#  'the',
#  'women',
#  'who',
#  'get',
#  'too',
#  'close',
#  'to',
#  'him',
#  '.',
#  'to',
#  'help',
#  'their',
#  'unemployed',
#  'father',
#  'make',
#  'ends',
#  'meet',
#  ',',
#  'edith',
#  'and',
#  'her',
#  'twin',
#  'sister',
#  'grace',
#  'work',
#  'as',
#  'seamstresses',
#  '.',
#  'an',
#  'invalid',
#  ',',
#  'grace',
#  'falls',
#  'prey',
#  'to',
#  'the',
#  'temptations',
#  'of',
#  'chinatown',
#  'opium',
#  'and',
#  'becomes',
#  'an',
#  'addict',
#  ',',
#  'a',
#  'condition',
#  'worsened',
#  'by',
#  'a',
#  'misguided',
#  'physician',
#  'who',
#  'prescribes',
#  'morphine',
#  'to',
#  'ease',
#  'her',
#  'pain',
#  '.',
#  'when',
#  'their',
#  'father',
#  'strikes',
#  'oil',
#  ',',
#  'the',
#  'family',
#  'enjoys',
#  'a',
#  'new',
#  'prosperity',
#  'and',
#  'the',
#  'sisters',
#  'meet',
#  'the',
#  'eligible',
#  'jack',
#  'herron',
#  ',',
#  'a',
#  'fellow',
#  'oil',
#  'prospector',
#  '.',
#  'to',
#  'grace',
#  "'s",
#  'shock',
#  ',',
#  'jack',
#  'falls',
#  'in',
#  'love',
#  'with',
#  'edith',
#  'and',
#  'in',
#  'her',
#  'jealousy',
#  ',',
#  'grace',
#  'tells',
#  'jack',
#  'that',
#  'edith',
#  ',',
#  'not',
#  'she',
#  ',',
#  'has',
#  'a',
#  'drug',
#  'problem',
#  '.',
#  'hinting',
#  'that',
#  'her',
#  'sister',
#  'will',
#  'soon',
#  'need',
#  'more',
#  'morphine',
#  ',',
#  'grace',
#  'arranges',
#  'for',
#  'a',
#  'dinner',
#  'in',
#  'chinatown',
#  'with',
#  'the',
#  'couple',
#  '.',
#  'while',
#  'her',
#  'sister',
#  'and',
#  'jack',
#  'dance',
#  ',',
#  'grace',
#  'slips',
#  'away',
#  'to',
#  'an',
#  'opium',
#  'den',
#  '.',
#  'edith',
#  'follows',
#  'her',
#  ',',
#  'but',
#  'ends',
#  'up',
#  'in',
#  'the',
#  'wrong',
#  'den',
#  'and',
#  'is',
#  'arrested',
#  'in',
#  'an',
#  'ensuing',
#  'drug',
#  'raid',
#  '.',
#  'after',
#  'he',
#  'bails',
#  'her',
#  'out',
#  'of',
#  'jail',
#  ',',
#  'edith',
#  'takes',
#  'an',
#  'angry',
#  'jack',
#  'to',
#  'search',
#  'for',
#  'grace',
#  'and',
#  'stumbles',
#  'across',
#  'her',
#  'half-conscious',
#  'body',
#  'lying',
#  'in',
#  'the',
#  'street',
#  '.',
#  'the',
#  'truth',
#  'about',
#  'the',
#  'sisters',
#  'is',
#  'revealed',
#  ',',
#  'and',
#  'after',
#  'sending',
#  'grace',
#  'to',
#  'a',
#  'sanitarium',
#  'in',
#  'the',
#  'country',
#  ',',
#  'jack',
#  'and',
#  'edith',
#  'are',
#  'married',
#  '.',
#  'the',
#  'film',
#  "'s",
#  'title',
#  'refers',
#  'not',
#  'only',
#  'to',
#  'the',
#  'un-recovered',
#  'bodies',
#  'at',
#  'ground',
#  'zero',
#  ',',
#  'but',
#  'also',
#  'to',
#  'the',
#  'state',
#  'of',
#  'the',
#  'nation',
#  'at',
#  'large',
#  '.',
#  'set',
#  'in',
#  'the',
#  'hallucinatory',
#  'period',
#  'of',
#  'time',
#  'between',
#  'september',
#  '11',
#  'and',
#  'halloween',
#  'of',
#  '2001',
#  ',',
#  'the',
#  'unrecovered',
#  'examines',
#  'the',
#  'effect',
#  'of',
#  'terror',
#  'on',
#  'the',
#  'average',
#  'mind',
#  ',',
#  'the',
#  'way',
#  'a',
#  'state',
#  'of',
#  'heightened',
#  'anxiety',
#  'and/or',
#  'alertness',
#  'can',
#  'cause',
#  'the',
#  'average',
#  'person',
#  'to',
#  'make',
#  'the',
#  'sort',
#  'of',
#  'imaginative',
#  'connections',
#  'that',
#  'are',
#  'normally',
#  'made',
#  'only',
#  'by',
#  'artists',
#  'and',
#  'conspiracy',
#  'theorists-both',
#  'of',
#  'whom',
#  'figure',
#  'prominently',
#  'in',
#  'this',
#  'film',
#  '.',
#  'the',
#  'unrecovered',
#  'explores',
#  'the',
#  'way',
#  'in',
#  'which',
#  'irony',
#  ',',
#  'empathy',
#  ',',
#  'and',
#  'paranoia',
#  'relate',
#  'to',
#  'one',
#  'another',
#  'in',
#  'the',
#  'wake',
#  'of',
#  '9/11',
#  '.',
#  'quality',
#  'control',
#  'consists',
#  'of',
#  'a',
#  'series',
#  'of',
#  '16mm',
#  'single',
#  'take',
#  'shots',
#  'filmed',
#  'in',
#  'the',
#  'summer',
#  'of',
#  '2010',
#  ',',
#  'over',
#  'a',
#  'two',
#  'day',
#  'period',
#  ',',
#  'in',
#  'a',
#  'dry',
#  'cleaners',
#  'facility',
#  'in',
#  'pritchard',
#  ',',
#  'alabama',
#  ',',
#  'near',
#  'mobile',
#  ',',
#  'quality',
#  'control',
#  'exhibits',
#  'the',
#  'acts',
#  'as',
#  'well',
#  'the',
#  'conditions',
#  'around',
#  'labor',
#  'and',
#  'showcases',
#  ',',
#  'in',
#  'everson',
#  "'s",
#  'words',
#  '``',
#  'the',
#  'fine',
#  'folks',
#  'of',
#  'alabama',
#  'producing',
#  'a',
#  'superior',
#  'product',
#  '.',
#  "''",
#  'it',
#  'is',
#  'similar',
#  'stylistically',
#  ',',
#  'in',
#  'form',
#  'and',
#  'rhythm',
#  ',',
#  'to',
#  'certain',
#  'scenarios',
#  'in',
#  'everson',
#  "'s",
#  'award-winning',
#  'and',
#  'critically',
#  'acclaimed',
#  'previous',
#  'films',
#  ',',
#  'including',
#  'erie',
#  '(',
#  'iffr',
#  '2010',
#  ')',
#  'and',
#  'in',
#  'thematic',
#  'concerns',
#  'to',
#  'several',
#  'other',
#  'short',
#  'form',
#  'works',
#  'which',
#  'follow',
#  'the',
#  'daily',
#  ',',
#  'quotidian',
#  'tasks',
#  'of',
#  'workers',
#  'in',
#  'rest',
#  'and',
#  'in',
#  'motion',
#  ',',
#  'and',
#  'is',
#  'an',
#  'oblique',
#  'sequel',
#  ',',
#  'ten',
#  'years',
#  'hence',
#  ',',
#  'to',
#  'everson',
#  "'s",
#  'creative',
#  'capital',
#  'granted',
#  'project',
#  'a',
#  'week',
#  'in',
#  'the',
#  'hole',
#  '(',
#  '2001',
#  ')',
#  ',',
#  'which',
#  'focused',
#  'on',
#  'an',
#  'employee',
#  "'s",
#  'adjustment',
#  'to',
#  'materials',
#  ',',
#  'time',
#  ',',
#  'space',
#  'and',
#  'personnel',
#  '.',
#  'quality',
#  'control',
#  'consists',
#  'of',
#  'a',
#  'series',
#  'of',
#  '16mm',
#  'single',
#  'take',
#  'shots',
#  ',',
#  'filmed',
#  'over',
#  'a',
#  'two',
#  'day',
#  'period',
#  'in',
#  'the',
#  'summer',
#  'of',
#  '2010',
#  ',',
#  'in',
#  'a',
#  'dry',
#  'cleaners',
#  'facility',
#  'in',
#  'pritchard',
#  ',',
#  'alabama',
#  ',',
#  'near',
#  'mobile',
#  '.',
#  'quality',
#  'control',
#  'exhibits',
#  'the',
#  'acts',
#  'as',
#  'well',
#  'the',
#  'conditions',
#  'around',
#  'labor',
#  '.',
#  'it',
#  'is',
#  'similar',
#  'stylistically',
#  ',',
#  'in',
#  'form',
#  'and',
#  'rhythm',
#  ',',
#  'to',
#  'certain',
#  'scenarios',
#  'in',
#  'everson',
#  "'s",
#  'award-winning',
#  'and',
#  'critically',
#  'acclaimed',
#  'previous',
#  'films',
#  ',',
#  'including',
#  'erie',
#  '(',
#  'iffr',
#  '2010',
#  ')',
#  'and',
#  'in',
#  'thematic',
#  'concerns',
#  'to',
#  'several',
#  'other',
#  'short',
#  'form',
#  'works',
#  'which',
#  'follow',
#  'the',
#  'daily',
#  ',',
#  'quotidian',
#  'tasks',
#  'of',
#  'workers',
#  'in',
#  'rest',
#  'and',
#  'in',
#  'motion',
#  ',',
#  'including',
#  'the',
#  'factory',
#  'routine',
#  'captured',
#  'in',
#  'the',
#  'short',
#  'film',
#  'a',
#  'week',
#  'in',
#  'the',
#  'hole',
#  '(',
#  '2001',
#  ')',
#  ',',
#  'which',
#  'focused',
#  'on',
#  'an',
#  'employee',
#  "'s",
#  'adjustment',
#  'to',
#  'materials',
#  ',',
#  'time',
#  ',',
#  'space',
#  'and',
#  'personnel',
#  '.',
#  'principal',
#  'cast',
#  'includes',
#  'shay',
#  'wright',
#  'and',
#  'annette',
#  'speight',
#  '.',
#  'in',
#  'tough',
#  'economic',
#  'times',
#  'max',
#  'and',
#  'joey',
#  'have',
#  'all',
#  'but',
#  'run',
#  'out',
#  'of',
#  'ideas',
#  'until',
#  ',',
#  'they',
#  'discover',
#  'that',
#  'senior',
#  'housing',
#  'is',
#  'cheap',
#  '.',
#  'not',
#  'only',
#  'that',
#  'but',
#  'max',
#  "'s",
#  'aunt',
#  'just',
#  'kicked',
#  'the',
#  'bucket',
#  'and',
#  'no',
#  'one',
#  'knows',
#  'yet',
#  '.',
#  'in',
#  'a',
#  'hilarious',
#  'series',
#  'that',
#  'always',
#  'keeps',
#  'you',
#  'on',
#  'your',
#  'toes',
#  ',',
#  'the',
#  'two',
#  'friends',
#  'take',
#  'us',
#  'on',
#  'a',
#  'cross-dressing',
#  ',',
#  'desperate',
#  'and',
#  'endearing',
#  'ride',
#  'through',
#  'being',
#  'broke',
#  '.',
#  'four',
#  'high',
#  'school',
#  'students',
#  'embark',
#  'on',
#  'a',
#  'terrifying',
#  'journey',
#  'through',
#  'shadowview',
#  'manor',
#  '2',
#  'years',
#  'after',
#  'a',
#  'horrifying',
#  'séance',
#  'gone',
#  'wrong',
#  '.',
#  'intern',
#  'raven',
#  ',',
#  'decides',
#  'to',
#  'reconnect',
#  'with',
#  'her',
#  'elementary',
#  'school',
#  'friends',
#  'kota',
#  ',',
#  'william',
#  ',',
#  'and',
#  'jessica',
#  'by',
#  'bringing',
#  'them',
#  'to',
#  'her',
#  'new',
#  'workplace',
#  ',',
#  'shadowview',
#  'manor',
#  'for',
#  'a',
#  'bit',
#  'of',
#  'paranormal',
#  'investigating',
#  '.',
#  'hearing',
#  'more',
#  'forbidden',
#  'secrets',
#  'from',
#  'the',
#  'night',
#  'janitor',
#  'sends',
#  'them',
#  'into',
#  'a',
#  'dark',
#  'descending',
#  'spiral',
#  'of',
#  'terror',
#  '.',
#  'tom',
#  'beacham',
#  'explores',
#  'ghana',
#  'with',
#  'director',
#  'of',
#  'photography',
#  'alex',
#  'holberton',
#  ',',
#  'in',
#  'search',
#  'of',
#  'spirits',
#  '.',
#  'the',
#  'film',
#  'looks',
#  'at',
#  'the',
#  'overlap',
#  'between',
#  'the',
#  'spirit',
#  'world',
#  'and',
#  'the',
#  'physical',
#  'world',
#  ',',
#  'voodoo',
#  ',',
#  'witchcraft',
#  ',',
#  'the',
#  'power',
#  'of',
#  'the',
#  'holy',
#  'spirit',
#  'and',
#  'magic',
#  '.',
#  'they',
#  'meet',
#  'with',
#  'royal',
#  'family',
#  'members',
#  ',',
#  'magicians',
#  'and',
#  'voodoo',
#  'priests',
#  'as',
#  'well',
#  'as',
#  'getting',
#  'rare',
#  'footage',
#  'of',
#  'a',
#  'full',
#  'voodoo',
#  'ceremony',
#  '.',
#  'danny',
#  ',',
#  'dying',
#  'of',
#  'aids',
#  ',',
#  'returns',
#  'home',
#  'for',
#  'his',
#  'last',
#  ...]

# %%
punct=string.punctuation

fill=[i for i in lower if i not in punct]

fill
# Out:
# ['listening',
#  'in',
#  'to',
#  'a',
#  'conversation',
#  'between',
#  'his',
#  'doctor',
#  'and',
#  'parents',
#  '10-year-old',
#  'oscar',
#  'learns',
#  'what',
#  'nobody',
#  'has',
#  'the',
#  'courage',
#  'to',
#  'tell',
#  'him',
#  'he',
#  'only',
#  'has',
#  'a',
#  'few',
#  'weeks',
#  'to',
#  'live',
#  'furious',
#  'he',
#  'refuses',
#  'to',
#  'speak',
#  'to',
#  'anyone',
#  'except',
#  'straight-talking',
#  'rose',
#  'the',
#  'lady',
#  'in',
#  'pink',
#  'he',
#  'meets',
#  'on',
#  'the',
#  'hospital',
#  'stairs',
#  'as',
#  'christmas',
#  'approaches',
#  'rose',
#  'uses',
#  'her',
#  'fantastical',
#  'experiences',
#  'as',
#  'a',
#  'professional',
#  'wrestler',
#  'her',
#  'imagination',
#  'wit',
#  'and',
#  'charm',
#  'to',
#  'allow',
#  'oscar',
#  'to',
#  'live',
#  'life',
#  'and',
#  'love',
#  'to',
#  'the',
#  'full',
#  'in',
#  'the',
#  'company',
#  'of',
#  'his',
#  'friends',
#  'pop',
#  'corn',
#  'einstein',
#  'bacon',
#  'and',
#  'childhood',
#  'sweetheart',
#  'peggy',
#  'blue',
#  'a',
#  'brother',
#  'and',
#  'sister',
#  'with',
#  'a',
#  'past',
#  'incestuous',
#  'relationship',
#  'have',
#  'a',
#  'current',
#  'murderous',
#  'relationship',
#  'he',
#  'murders',
#  'the',
#  'women',
#  'who',
#  'reject',
#  'him',
#  'and',
#  'she',
#  'murders',
#  'the',
#  'women',
#  'who',
#  'get',
#  'too',
#  'close',
#  'to',
#  'him',
#  'to',
#  'help',
#  'their',
#  'unemployed',
#  'father',
#  'make',
#  'ends',
#  'meet',
#  'edith',
#  'and',
#  'her',
#  'twin',
#  'sister',
#  'grace',
#  'work',
#  'as',
#  'seamstresses',
#  'an',
#  'invalid',
#  'grace',
#  'falls',
#  'prey',
#  'to',
#  'the',
#  'temptations',
#  'of',
#  'chinatown',
#  'opium',
#  'and',
#  'becomes',
#  'an',
#  'addict',
#  'a',
#  'condition',
#  'worsened',
#  'by',
#  'a',
#  'misguided',
#  'physician',
#  'who',
#  'prescribes',
#  'morphine',
#  'to',
#  'ease',
#  'her',
#  'pain',
#  'when',
#  'their',
#  'father',
#  'strikes',
#  'oil',
#  'the',
#  'family',
#  'enjoys',
#  'a',
#  'new',
#  'prosperity',
#  'and',
#  'the',
#  'sisters',
#  'meet',
#  'the',
#  'eligible',
#  'jack',
#  'herron',
#  'a',
#  'fellow',
#  'oil',
#  'prospector',
#  'to',
#  'grace',
#  "'s",
#  'shock',
#  'jack',
#  'falls',
#  'in',
#  'love',
#  'with',
#  'edith',
#  'and',
#  'in',
#  'her',
#  'jealousy',
#  'grace',
#  'tells',
#  'jack',
#  'that',
#  'edith',
#  'not',
#  'she',
#  'has',
#  'a',
#  'drug',
#  'problem',
#  'hinting',
#  'that',
#  'her',
#  'sister',
#  'will',
#  'soon',
#  'need',
#  'more',
#  'morphine',
#  'grace',
#  'arranges',
#  'for',
#  'a',
#  'dinner',
#  'in',
#  'chinatown',
#  'with',
#  'the',
#  'couple',
#  'while',
#  'her',
#  'sister',
#  'and',
#  'jack',
#  'dance',
#  'grace',
#  'slips',
#  'away',
#  'to',
#  'an',
#  'opium',
#  'den',
#  'edith',
#  'follows',
#  'her',
#  'but',
#  'ends',
#  'up',
#  'in',
#  'the',
#  'wrong',
#  'den',
#  'and',
#  'is',
#  'arrested',
#  'in',
#  'an',
#  'ensuing',
#  'drug',
#  'raid',
#  'after',
#  'he',
#  'bails',
#  'her',
#  'out',
#  'of',
#  'jail',
#  'edith',
#  'takes',
#  'an',
#  'angry',
#  'jack',
#  'to',
#  'search',
#  'for',
#  'grace',
#  'and',
#  'stumbles',
#  'across',
#  'her',
#  'half-conscious',
#  'body',
#  'lying',
#  'in',
#  'the',
#  'street',
#  'the',
#  'truth',
#  'about',
#  'the',
#  'sisters',
#  'is',
#  'revealed',
#  'and',
#  'after',
#  'sending',
#  'grace',
#  'to',
#  'a',
#  'sanitarium',
#  'in',
#  'the',
#  'country',
#  'jack',
#  'and',
#  'edith',
#  'are',
#  'married',
#  'the',
#  'film',
#  "'s",
#  'title',
#  'refers',
#  'not',
#  'only',
#  'to',
#  'the',
#  'un-recovered',
#  'bodies',
#  'at',
#  'ground',
#  'zero',
#  'but',
#  'also',
#  'to',
#  'the',
#  'state',
#  'of',
#  'the',
#  'nation',
#  'at',
#  'large',
#  'set',
#  'in',
#  'the',
#  'hallucinatory',
#  'period',
#  'of',
#  'time',
#  'between',
#  'september',
#  '11',
#  'and',
#  'halloween',
#  'of',
#  '2001',
#  'the',
#  'unrecovered',
#  'examines',
#  'the',
#  'effect',
#  'of',
#  'terror',
#  'on',
#  'the',
#  'average',
#  'mind',
#  'the',
#  'way',
#  'a',
#  'state',
#  'of',
#  'heightened',
#  'anxiety',
#  'and/or',
#  'alertness',
#  'can',
#  'cause',
#  'the',
#  'average',
#  'person',
#  'to',
#  'make',
#  'the',
#  'sort',
#  'of',
#  'imaginative',
#  'connections',
#  'that',
#  'are',
#  'normally',
#  'made',
#  'only',
#  'by',
#  'artists',
#  'and',
#  'conspiracy',
#  'theorists-both',
#  'of',
#  'whom',
#  'figure',
#  'prominently',
#  'in',
#  'this',
#  'film',
#  'the',
#  'unrecovered',
#  'explores',
#  'the',
#  'way',
#  'in',
#  'which',
#  'irony',
#  'empathy',
#  'and',
#  'paranoia',
#  'relate',
#  'to',
#  'one',
#  'another',
#  'in',
#  'the',
#  'wake',
#  'of',
#  '9/11',
#  'quality',
#  'control',
#  'consists',
#  'of',
#  'a',
#  'series',
#  'of',
#  '16mm',
#  'single',
#  'take',
#  'shots',
#  'filmed',
#  'in',
#  'the',
#  'summer',
#  'of',
#  '2010',
#  'over',
#  'a',
#  'two',
#  'day',
#  'period',
#  'in',
#  'a',
#  'dry',
#  'cleaners',
#  'facility',
#  'in',
#  'pritchard',
#  'alabama',
#  'near',
#  'mobile',
#  'quality',
#  'control',
#  'exhibits',
#  'the',
#  'acts',
#  'as',
#  'well',
#  'the',
#  'conditions',
#  'around',
#  'labor',
#  'and',
#  'showcases',
#  'in',
#  'everson',
#  "'s",
#  'words',
#  '``',
#  'the',
#  'fine',
#  'folks',
#  'of',
#  'alabama',
#  'producing',
#  'a',
#  'superior',
#  'product',
#  "''",
#  'it',
#  'is',
#  'similar',
#  'stylistically',
#  'in',
#  'form',
#  'and',
#  'rhythm',
#  'to',
#  'certain',
#  'scenarios',
#  'in',
#  'everson',
#  "'s",
#  'award-winning',
#  'and',
#  'critically',
#  'acclaimed',
#  'previous',
#  'films',
#  'including',
#  'erie',
#  'iffr',
#  '2010',
#  'and',
#  'in',
#  'thematic',
#  'concerns',
#  'to',
#  'several',
#  'other',
#  'short',
#  'form',
#  'works',
#  'which',
#  'follow',
#  'the',
#  'daily',
#  'quotidian',
#  'tasks',
#  'of',
#  'workers',
#  'in',
#  'rest',
#  'and',
#  'in',
#  'motion',
#  'and',
#  'is',
#  'an',
#  'oblique',
#  'sequel',
#  'ten',
#  'years',
#  'hence',
#  'to',
#  'everson',
#  "'s",
#  'creative',
#  'capital',
#  'granted',
#  'project',
#  'a',
#  'week',
#  'in',
#  'the',
#  'hole',
#  '2001',
#  'which',
#  'focused',
#  'on',
#  'an',
#  'employee',
#  "'s",
#  'adjustment',
#  'to',
#  'materials',
#  'time',
#  'space',
#  'and',
#  'personnel',
#  'quality',
#  'control',
#  'consists',
#  'of',
#  'a',
#  'series',
#  'of',
#  '16mm',
#  'single',
#  'take',
#  'shots',
#  'filmed',
#  'over',
#  'a',
#  'two',
#  'day',
#  'period',
#  'in',
#  'the',
#  'summer',
#  'of',
#  '2010',
#  'in',
#  'a',
#  'dry',
#  'cleaners',
#  'facility',
#  'in',
#  'pritchard',
#  'alabama',
#  'near',
#  'mobile',
#  'quality',
#  'control',
#  'exhibits',
#  'the',
#  'acts',
#  'as',
#  'well',
#  'the',
#  'conditions',
#  'around',
#  'labor',
#  'it',
#  'is',
#  'similar',
#  'stylistically',
#  'in',
#  'form',
#  'and',
#  'rhythm',
#  'to',
#  'certain',
#  'scenarios',
#  'in',
#  'everson',
#  "'s",
#  'award-winning',
#  'and',
#  'critically',
#  'acclaimed',
#  'previous',
#  'films',
#  'including',
#  'erie',
#  'iffr',
#  '2010',
#  'and',
#  'in',
#  'thematic',
#  'concerns',
#  'to',
#  'several',
#  'other',
#  'short',
#  'form',
#  'works',
#  'which',
#  'follow',
#  'the',
#  'daily',
#  'quotidian',
#  'tasks',
#  'of',
#  'workers',
#  'in',
#  'rest',
#  'and',
#  'in',
#  'motion',
#  'including',
#  'the',
#  'factory',
#  'routine',
#  'captured',
#  'in',
#  'the',
#  'short',
#  'film',
#  'a',
#  'week',
#  'in',
#  'the',
#  'hole',
#  '2001',
#  'which',
#  'focused',
#  'on',
#  'an',
#  'employee',
#  "'s",
#  'adjustment',
#  'to',
#  'materials',
#  'time',
#  'space',
#  'and',
#  'personnel',
#  'principal',
#  'cast',
#  'includes',
#  'shay',
#  'wright',
#  'and',
#  'annette',
#  'speight',
#  'in',
#  'tough',
#  'economic',
#  'times',
#  'max',
#  'and',
#  'joey',
#  'have',
#  'all',
#  'but',
#  'run',
#  'out',
#  'of',
#  'ideas',
#  'until',
#  'they',
#  'discover',
#  'that',
#  'senior',
#  'housing',
#  'is',
#  'cheap',
#  'not',
#  'only',
#  'that',
#  'but',
#  'max',
#  "'s",
#  'aunt',
#  'just',
#  'kicked',
#  'the',
#  'bucket',
#  'and',
#  'no',
#  'one',
#  'knows',
#  'yet',
#  'in',
#  'a',
#  'hilarious',
#  'series',
#  'that',
#  'always',
#  'keeps',
#  'you',
#  'on',
#  'your',
#  'toes',
#  'the',
#  'two',
#  'friends',
#  'take',
#  'us',
#  'on',
#  'a',
#  'cross-dressing',
#  'desperate',
#  'and',
#  'endearing',
#  'ride',
#  'through',
#  'being',
#  'broke',
#  'four',
#  'high',
#  'school',
#  'students',
#  'embark',
#  'on',
#  'a',
#  'terrifying',
#  'journey',
#  'through',
#  'shadowview',
#  'manor',
#  '2',
#  'years',
#  'after',
#  'a',
#  'horrifying',
#  'séance',
#  'gone',
#  'wrong',
#  'intern',
#  'raven',
#  'decides',
#  'to',
#  'reconnect',
#  'with',
#  'her',
#  'elementary',
#  'school',
#  'friends',
#  'kota',
#  'william',
#  'and',
#  'jessica',
#  'by',
#  'bringing',
#  'them',
#  'to',
#  'her',
#  'new',
#  'workplace',
#  'shadowview',
#  'manor',
#  'for',
#  'a',
#  'bit',
#  'of',
#  'paranormal',
#  'investigating',
#  'hearing',
#  'more',
#  'forbidden',
#  'secrets',
#  'from',
#  'the',
#  'night',
#  'janitor',
#  'sends',
#  'them',
#  'into',
#  'a',
#  'dark',
#  'descending',
#  'spiral',
#  'of',
#  'terror',
#  'tom',
#  'beacham',
#  'explores',
#  'ghana',
#  'with',
#  'director',
#  'of',
#  'photography',
#  'alex',
#  'holberton',
#  'in',
#  'search',
#  'of',
#  'spirits',
#  'the',
#  'film',
#  'looks',
#  'at',
#  'the',
#  'overlap',
#  'between',
#  'the',
#  'spirit',
#  'world',
#  'and',
#  'the',
#  'physical',
#  'world',
#  'voodoo',
#  'witchcraft',
#  'the',
#  'power',
#  'of',
#  'the',
#  'holy',
#  'spirit',
#  'and',
#  'magic',
#  'they',
#  'meet',
#  'with',
#  'royal',
#  'family',
#  'members',
#  'magicians',
#  'and',
#  'voodoo',
#  'priests',
#  'as',
#  'well',
#  'as',
#  'getting',
#  'rare',
#  'footage',
#  'of',
#  'a',
#  'full',
#  'voodoo',
#  'ceremony',
#  'danny',
#  'dying',
#  'of',
#  'aids',
#  'returns',
#  'home',
#  'for',
#  'his',
#  'last',
#  'months',
#  'always',
#  'close',
#  'to',
#  'his',
#  'mother',
#  'they',
#  'share',
#  'moments',
#  'of',
#  'openness',
#  'that',
#  'tend',
#  'to',
#  'shut',
#  'out',
#  'danny',
#  "'s",
#  'father',
#  'and',
#  'his',
#  'sister',
#  'a',
#  'sister',
#  "'s",
#  'breast',
#  'cancer',
#  'diagnosis',
#  'and',
#  'her',
#  'brother',
#  "'s",
#  'need',
#  'to',
#  'take',
#  'action',
#  'highlighting',
#  'the',
#  'events',
#  'that',
#  'took',
#  'place',
#  'during',
#  'franke',
#  "'s",
#  'participation',
#  'in',
#  'the',
#  'susan',
#  'g.',
#  'komen',
#  '3-day',
#  'walk',
#  'including',
#  'the',
#  'training',
#  'and',
#  'fund-raising',
#  'events',
#  'in',
#  'the',
#  'six',
#  'months',
#  'preceding',
#  'the',
#  'walk',
#  'it',
#  'includes',
#  'numerous',
#  'interviews',
#  'with',
#  'breast',
#  'cancer',
#  'survivors',
#  'who',
#  'share',
#  'the',
#  'wealth',
#  'of',
#  'their',
#  'experience',
#  'with',
#  'the',
#  'viewer',
#  'also',
#  'included',
#  'are',
#  'appearances',
#  'by',
#  'local',
#  'celebrities',
#  'athletes',
#  'and',
#  'musical',
#  'artists',
#  'as',
#  'well',
#  'as',
#  'informative',
#  'interviews',
#  'with',
#  'health',
#  'care',
#  'professionals',
#  'who',
#  'explain',
#  'what',
#  'we',
#  'should',
#  'all',
#  'know',
#  'about',
#  ...]

# %%
from nltk.corpus import stopwords
stopwords=stopwords.words('english')
stopwords
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
#  'down',
#  'in',
#  'out',
#  'on',
#  'off',
#  'over',
#  'under',
#  'again',
#  'further',
#  'then',
#  'once',
#  'here',
#  'there',
#  'when',
#  'where',
#  'why',
#  'how',
#  'all',
#  'any',
#  'both',
#  'each',
#  'few',
#  'more',
#  'most',
#  'other',
#  'some',
#  'such',
#  'no',
#  'nor',
#  'not',
#  'only',
#  'own',
#  'same',
#  'so',
#  'than',
#  'too',
#  'very',
#  's',
#  't',
#  'can',
#  'will',
#  'just',
#  'don',
#  "don't",
#  'should',
#  "should've",
#  'now',
#  'd',
#  'll',
#  'm',
#  'o',
#  're',
#  've',
#  'y',
#  'ain',
#  'aren',
#  "aren't",
#  'couldn',
#  "couldn't",
#  'didn',
#  "didn't",
#  'doesn',
#  "doesn't",
#  'hadn',
#  "hadn't",
#  'hasn',
#  "hasn't",
#  'haven',
#  "haven't",
#  'isn',
#  "isn't",
#  'ma',
#  'mightn',
#  "mightn't",
#  'mustn',
#  "mustn't",
#  'needn',
#  "needn't",
#  'shan',
#  "shan't",
#  'shouldn',
#  "shouldn't",
#  'wasn',
#  "wasn't",
#  'weren',
#  "weren't",
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't"]

# %%
remove = ['don', "don't", 'should', "aren'", "aren't", "couldn'", "couldn't",
          "didn'", "didn't", "doesn'", "doesn't", "hadn'", "hadn't", "hasn'",          
          "hasn't", "haven'", "haven't", "isn'", "isn't", "mightn'", "mightn't",
          "mustn'", "mustn't", "needn'", "needn't", "shan'", "shan't", "shouldn'",
          "shouldn't", "wasn'", "wasn't", "weren'", "weren't", "won'", "won't",
          "wouldn'", "wouldn't"]

# %%
stopwords=set(stopwords)-set(remove)
stopwords
# Out:
# {'a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  'd',
#  'did',
#  'didn',
#  'do',
#  'does',
#  'doesn',
#  'doing',
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  'has',
#  'hasn',
#  'have',
#  'haven',
#  'having',
#  'he',
#  'her',
#  'here',
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  'if',
#  'in',
#  'into',
#  'is',
#  'isn',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'just',
#  'll',
#  'm',
#  'ma',
#  'me',
#  'mightn',
#  'more',
#  'most',
#  'mustn',
#  'my',
#  'myself',
#  'needn',
#  'no',
#  'nor',
#  'not',
#  'now',
#  'o',
#  'of',
#  'off',
#  'on',
#  'once',
#  'only',
#  'or',
#  'other',
#  'our',
#  'ours',
#  'ourselves',
#  'out',
#  'over',
#  'own',
#  're',
#  's',
#  'same',
#  'shan',
#  'she',
#  "she's",
#  "should've",
#  'shouldn',
#  'so',
#  'some',
#  'such',
#  't',
#  'than',
#  'that',
#  "that'll",
#  'the',
#  'their',
#  'theirs',
#  'them',
#  'themselves',
#  'then',
#  'there',
#  'these',
#  'they',
#  'this',
#  'those',
#  'through',
#  'to',
#  'too',
#  'under',
#  'until',
#  'up',
#  've',
#  'very',
#  'was',
#  'wasn',
#  'we',
#  'were',
#  'weren',
#  'what',
#  'when',
#  'where',
#  'which',
#  'while',
#  'who',
#  'whom',
#  'why',
#  'will',
#  'with',
#  'won',
#  'wouldn',
#  'y',
#  'you',
#  "you'd",
#  "you'll",
#  "you're",
#  "you've",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves'}

# %%
filter=[i for i in fill if i not in stopwords]

filter
# Out:
# ['listening',
#  'conversation',
#  'doctor',
#  'parents',
#  '10-year-old',
#  'oscar',
#  'learns',
#  'nobody',
#  'courage',
#  'tell',
#  'weeks',
#  'live',
#  'furious',
#  'refuses',
#  'speak',
#  'anyone',
#  'except',
#  'straight-talking',
#  'rose',
#  'lady',
#  'pink',
#  'meets',
#  'hospital',
#  'stairs',
#  'christmas',
#  'approaches',
#  'rose',
#  'uses',
#  'fantastical',
#  'experiences',
#  'professional',
#  'wrestler',
#  'imagination',
#  'wit',
#  'charm',
#  'allow',
#  'oscar',
#  'live',
#  'life',
#  'love',
#  'full',
#  'company',
#  'friends',
#  'pop',
#  'corn',
#  'einstein',
#  'bacon',
#  'childhood',
#  'sweetheart',
#  'peggy',
#  'blue',
#  'brother',
#  'sister',
#  'past',
#  'incestuous',
#  'relationship',
#  'current',
#  'murderous',
#  'relationship',
#  'murders',
#  'women',
#  'reject',
#  'murders',
#  'women',
#  'get',
#  'close',
#  'help',
#  'unemployed',
#  'father',
#  'make',
#  'ends',
#  'meet',
#  'edith',
#  'twin',
#  'sister',
#  'grace',
#  'work',
#  'seamstresses',
#  'invalid',
#  'grace',
#  'falls',
#  'prey',
#  'temptations',
#  'chinatown',
#  'opium',
#  'becomes',
#  'addict',
#  'condition',
#  'worsened',
#  'misguided',
#  'physician',
#  'prescribes',
#  'morphine',
#  'ease',
#  'pain',
#  'father',
#  'strikes',
#  'oil',
#  'family',
#  'enjoys',
#  'new',
#  'prosperity',
#  'sisters',
#  'meet',
#  'eligible',
#  'jack',
#  'herron',
#  'fellow',
#  'oil',
#  'prospector',
#  'grace',
#  "'s",
#  'shock',
#  'jack',
#  'falls',
#  'love',
#  'edith',
#  'jealousy',
#  'grace',
#  'tells',
#  'jack',
#  'edith',
#  'drug',
#  'problem',
#  'hinting',
#  'sister',
#  'soon',
#  'need',
#  'morphine',
#  'grace',
#  'arranges',
#  'dinner',
#  'chinatown',
#  'couple',
#  'sister',
#  'jack',
#  'dance',
#  'grace',
#  'slips',
#  'away',
#  'opium',
#  'den',
#  'edith',
#  'follows',
#  'ends',
#  'wrong',
#  'den',
#  'arrested',
#  'ensuing',
#  'drug',
#  'raid',
#  'bails',
#  'jail',
#  'edith',
#  'takes',
#  'angry',
#  'jack',
#  'search',
#  'grace',
#  'stumbles',
#  'across',
#  'half-conscious',
#  'body',
#  'lying',
#  'street',
#  'truth',
#  'sisters',
#  'revealed',
#  'sending',
#  'grace',
#  'sanitarium',
#  'country',
#  'jack',
#  'edith',
#  'married',
#  'film',
#  "'s",
#  'title',
#  'refers',
#  'un-recovered',
#  'bodies',
#  'ground',
#  'zero',
#  'also',
#  'state',
#  'nation',
#  'large',
#  'set',
#  'hallucinatory',
#  'period',
#  'time',
#  'september',
#  '11',
#  'halloween',
#  '2001',
#  'unrecovered',
#  'examines',
#  'effect',
#  'terror',
#  'average',
#  'mind',
#  'way',
#  'state',
#  'heightened',
#  'anxiety',
#  'and/or',
#  'alertness',
#  'cause',
#  'average',
#  'person',
#  'make',
#  'sort',
#  'imaginative',
#  'connections',
#  'normally',
#  'made',
#  'artists',
#  'conspiracy',
#  'theorists-both',
#  'figure',
#  'prominently',
#  'film',
#  'unrecovered',
#  'explores',
#  'way',
#  'irony',
#  'empathy',
#  'paranoia',
#  'relate',
#  'one',
#  'another',
#  'wake',
#  '9/11',
#  'quality',
#  'control',
#  'consists',
#  'series',
#  '16mm',
#  'single',
#  'take',
#  'shots',
#  'filmed',
#  'summer',
#  '2010',
#  'two',
#  'day',
#  'period',
#  'dry',
#  'cleaners',
#  'facility',
#  'pritchard',
#  'alabama',
#  'near',
#  'mobile',
#  'quality',
#  'control',
#  'exhibits',
#  'acts',
#  'well',
#  'conditions',
#  'around',
#  'labor',
#  'showcases',
#  'everson',
#  "'s",
#  'words',
#  '``',
#  'fine',
#  'folks',
#  'alabama',
#  'producing',
#  'superior',
#  'product',
#  "''",
#  'similar',
#  'stylistically',
#  'form',
#  'rhythm',
#  'certain',
#  'scenarios',
#  'everson',
#  "'s",
#  'award-winning',
#  'critically',
#  'acclaimed',
#  'previous',
#  'films',
#  'including',
#  'erie',
#  'iffr',
#  '2010',
#  'thematic',
#  'concerns',
#  'several',
#  'short',
#  'form',
#  'works',
#  'follow',
#  'daily',
#  'quotidian',
#  'tasks',
#  'workers',
#  'rest',
#  'motion',
#  'oblique',
#  'sequel',
#  'ten',
#  'years',
#  'hence',
#  'everson',
#  "'s",
#  'creative',
#  'capital',
#  'granted',
#  'project',
#  'week',
#  'hole',
#  '2001',
#  'focused',
#  'employee',
#  "'s",
#  'adjustment',
#  'materials',
#  'time',
#  'space',
#  'personnel',
#  'quality',
#  'control',
#  'consists',
#  'series',
#  '16mm',
#  'single',
#  'take',
#  'shots',
#  'filmed',
#  'two',
#  'day',
#  'period',
#  'summer',
#  '2010',
#  'dry',
#  'cleaners',
#  'facility',
#  'pritchard',
#  'alabama',
#  'near',
#  'mobile',
#  'quality',
#  'control',
#  'exhibits',
#  'acts',
#  'well',
#  'conditions',
#  'around',
#  'labor',
#  'similar',
#  'stylistically',
#  'form',
#  'rhythm',
#  'certain',
#  'scenarios',
#  'everson',
#  "'s",
#  'award-winning',
#  'critically',
#  'acclaimed',
#  'previous',
#  'films',
#  'including',
#  'erie',
#  'iffr',
#  '2010',
#  'thematic',
#  'concerns',
#  'several',
#  'short',
#  'form',
#  'works',
#  'follow',
#  'daily',
#  'quotidian',
#  'tasks',
#  'workers',
#  'rest',
#  'motion',
#  'including',
#  'factory',
#  'routine',
#  'captured',
#  'short',
#  'film',
#  'week',
#  'hole',
#  '2001',
#  'focused',
#  'employee',
#  "'s",
#  'adjustment',
#  'materials',
#  'time',
#  'space',
#  'personnel',
#  'principal',
#  'cast',
#  'includes',
#  'shay',
#  'wright',
#  'annette',
#  'speight',
#  'tough',
#  'economic',
#  'times',
#  'max',
#  'joey',
#  'run',
#  'ideas',
#  'discover',
#  'senior',
#  'housing',
#  'cheap',
#  'max',
#  "'s",
#  'aunt',
#  'kicked',
#  'bucket',
#  'one',
#  'knows',
#  'yet',
#  'hilarious',
#  'series',
#  'always',
#  'keeps',
#  'toes',
#  'two',
#  'friends',
#  'take',
#  'us',
#  'cross-dressing',
#  'desperate',
#  'endearing',
#  'ride',
#  'broke',
#  'four',
#  'high',
#  'school',
#  'students',
#  'embark',
#  'terrifying',
#  'journey',
#  'shadowview',
#  'manor',
#  '2',
#  'years',
#  'horrifying',
#  'séance',
#  'gone',
#  'wrong',
#  'intern',
#  'raven',
#  'decides',
#  'reconnect',
#  'elementary',
#  'school',
#  'friends',
#  'kota',
#  'william',
#  'jessica',
#  'bringing',
#  'new',
#  'workplace',
#  'shadowview',
#  'manor',
#  'bit',
#  'paranormal',
#  'investigating',
#  'hearing',
#  'forbidden',
#  'secrets',
#  'night',
#  'janitor',
#  'sends',
#  'dark',
#  'descending',
#  'spiral',
#  'terror',
#  'tom',
#  'beacham',
#  'explores',
#  'ghana',
#  'director',
#  'photography',
#  'alex',
#  'holberton',
#  'search',
#  'spirits',
#  'film',
#  'looks',
#  'overlap',
#  'spirit',
#  'world',
#  'physical',
#  'world',
#  'voodoo',
#  'witchcraft',
#  'power',
#  'holy',
#  'spirit',
#  'magic',
#  'meet',
#  'royal',
#  'family',
#  'members',
#  'magicians',
#  'voodoo',
#  'priests',
#  'well',
#  'getting',
#  'rare',
#  'footage',
#  'full',
#  'voodoo',
#  'ceremony',
#  'danny',
#  'dying',
#  'aids',
#  'returns',
#  'home',
#  'last',
#  'months',
#  'always',
#  'close',
#  'mother',
#  'share',
#  'moments',
#  'openness',
#  'tend',
#  'shut',
#  'danny',
#  "'s",
#  'father',
#  'sister',
#  'sister',
#  "'s",
#  'breast',
#  'cancer',
#  'diagnosis',
#  'brother',
#  "'s",
#  'need',
#  'take',
#  'action',
#  'highlighting',
#  'events',
#  'took',
#  'place',
#  'franke',
#  "'s",
#  'participation',
#  'susan',
#  'g.',
#  'komen',
#  '3-day',
#  'walk',
#  'including',
#  'training',
#  'fund-raising',
#  'events',
#  'six',
#  'months',
#  'preceding',
#  'walk',
#  'includes',
#  'numerous',
#  'interviews',
#  'breast',
#  'cancer',
#  'survivors',
#  'share',
#  'wealth',
#  'experience',
#  'viewer',
#  'also',
#  'included',
#  'appearances',
#  'local',
#  'celebrities',
#  'athletes',
#  'musical',
#  'artists',
#  'well',
#  'informative',
#  'interviews',
#  'health',
#  'care',
#  'professionals',
#  'explain',
#  'should',
#  'know',
#  'dealing',
#  'illness',
#  'film',
#  'doctor',
#  'should',
#  'given',
#  'sister',
#  'left',
#  'office',
#  'fateful',
#  'day',
#  'made',
#  'film',
#  'sister',
#  'sisters',
#  '...',
#  'would',
#  'always',
#  'remember',
#  '``',
#  'alone',
#  "''",
#  'photographer',
#  'sailing',
#  'wife',
#  'sister',
#  'nympho-maniacal',
#  'model',
#  'leaves',
#  'three',
#  'women',
#  'alone',
#  'get',
#  'part',
#  'boat',
#  'mysterious',
#  'man',
#  'shows',
#  'might',
#  'escaped',
#  'criminal',
#  'police',
#  'searching',
#  "n't",
#  'alarm',
#  'three',
#  'women',
#  'much',
#  'rapidly',
#  'seduces',
#  'three',
#  'amanda',
#  'wingfield',
#  'dominates',
#  'children',
#  'faded',
#  'gentility',
#  'exaggerated',
#  'tales',
#  'southern',
#  'belle',
#  'past',
#  'son',
#  'plans',
#  'escape',
#  'daughter',
#  'withdraws',
#  'dream',
#  'world',
#  '``',
#  'gentleman',
#  'caller',
#  "''",
#  'appears',
#  'things',
#  'move',
#  'crisis',
#  'point',
#  'amanda',
#  'faced',
#  'dilemma',
#  'dependent',
#  'life',
#  'remaining',
#  'years',
#  'importantly',
#  'dependent',
#  'daughter',
#  'laura',
#  'amanda',
#  'struggles',
#  'use',
#  'means',
#  'disposable',
#  'secure',
#  'future',
#  'frightened',
#  'fragile',
#  '``',
#  'spinster',
#  "''",
#  'daughter',
#  'simon',
#  "'s",
#  'world',
#  'turned',
#  'upside',
#  'little',
#  'girl',
#  'katie',
#  'abducted',
#  'family',
#  'day',
#  'weeks',
#  'searching',
#  'appeals',
#  'simon',
#  'decides',
#  'punish',
#  'offering',
#  'young',
#  'prostitute',
#  'mounting',
#  'debts',
#  'life',
#  'changing',
#  'money',
#  'end',
#  'life',
#  'frankie',
#  'reno',
#  'child',
#  'star',
#  'tv',
#  'show',
#  'thirty',
#  'years',
#  'ago',
#  "'s",
#  'busy',
#  'making',
#  'ends',
#  'meet',
#  'running',
#  '``',
#  'babylon',
#  'vista',
#  "''",
#  'hollywood',
#  'apartment',
#  'inhabited',
#  'has-beens',
#  'wannabees',
#  'stories',
#  'rent',
#  'payments',
#  'frankie',
#  'slowly',
#  'finds',
#  'getting',
#  'sucked',
#  'bizarre',
#  'world',
#  'dysfunctional',
#  'tenants',
#  'story',
#  'castle',
#  'family',
#  'norbert',
#  'salburg-falkenstein',
#  'commander',
#  'knights',
#  'malte',
#  'österreich',
#  'bohemia',
#  'married',
#  'daughter',
#  'naval',
#  'commander',
#  'sweden',
#  'able',
#  'restore',
#  'family',
#  'property',
#  'correctly',
#  'help',
#  'wagnerian',
#  'opera',
#  'singer',
#  'sings',
#  'welsh',
#  'wagnerian',
#  'music',
#  'video',
#  'one',
#  'series',
#  'nobility',
#  'deutschland',
#  'österreich',
#  'live',
#  'various',
#  'castles',
#  'lively',
#  'fun',
#  'commentary',
#  'tv',
#  'hosts',
#  'one',
#  'descendant',
#  'great',
#  'hapsburg',
#  'dynasty',
#  'road',
#  'milk',
#  'narrates',
#  'existential',
#  'drama',
#  'tones',
#  'story',
#  'man',
#  'searching',
#  'lost',
#  'time',
#  'traveling',
#  'across',
#  'roads',
#  'brazil',
#  "'s",
#  'countryside',
#  'making',
#  'way',
#  'back',
#  'homeland',
#  'journey',
#  'find',
#  'way',
#  'sign',
#  'past',
#  'remake',
#  'life',
#  'show',
#  'path',
#  'salvation',
#  'threshold',
#  'reason',
#  'madness',
#  'salvation',
#  'death',
#  'gang',
#  'unemployed',
#  'itinerant',
#  'musicians',
#  'play',
#  'south',
#  'stockholm',
#  'get',
#  'chance',
#  'orchestra',
#  'dance',
#  'restaurant',
#  'goes',
#  'well',
#  'female',
#  'owner',
#  'falls',
#  'love',
#  'one',
#  'committee',
#  'investigating',
#  'tv',
#  "'s",
#  'first',
#  'uncensored',
#  'network',
#  'examines',
#  'typical',
#  'day',
#  "'s",
#  'programming',
#  'includes',
#  'shows',
#  'commercials',
#  'news',
#  'programs',
#  'name',
#  'discover',
#  'surely',
#  'crack',
#  'outrageous',
#  'irreverent',
#  'spoof',
#  'television',
#  'launched',
#  'careers',
#  'greatest',
#  'comedians',
#  'time',
#  '1976',
#  'film',
#  'tries',
#  'predict',
#  'american',
#  'television',
#  'like',
#  'year',
#  '1985',
#  'tunnelvision',
#  'america',
#  "'s",
#  'first',
#  '``',
#  'uncensored',
#  'free',
#  "''",
#  'television',
#  'network',
#  'although',
#  'wildly',
#  'popular',
#  'also',
#  'blamed',
#  'increased',
#  'crime',
#  'unemployment',
#  'christian',
#  'a.',
#  'broder',
#  'president',
#  'founder',
#  'tunnelvision',
#  'called',
#  'defend',
#  'network',
#  'front',
#  'senate',
#  'sub-committee',
#  'sub-committee',
#  'decides',
#  'view',
#  'excerpts',
#  '``',
#  'typical',
#  "''",
#  'day',
#  'tunnelvision',
#  'broadcasting',
#  'follows',
#  'series',
#  'brief',
#  'skits',
#  'lampooning',
#  'television',
#  'including',
#  'cop',
#  'shows',
#  'news',
#  'broadcasts',
#  'situation',
#  'comedies',
#  'course',
#  'commercials',
#  'wedded',
#  'bliss',
#  'explores',
#  'perception',
#  'one',
#  "'s",
#  'wedding',
#  'one',
#  "'s",
#  'newly',
#  'wedded',
#  'life',
#  'perfect',
#  'romantic',
#  'time',
#  'one',
#  "'s",
#  'life',
#  'reality',
#  'many',
#  'people',
#  'two',
#  'families',
#  'coming',
#  'together',
#  'almost',
#  'always',
#  '``',
#  'miscommunication',
#  "''",
#  'always',
#  'start',
#  'small',
#  'become',
#  'bigger',
#  'baggage',
#  'becomes',
#  'big',
#  'distraction',
#  'new',
#  'couple',
#  ...]

# %%
from nltk.stem import PorterStemmer
from nltk.stem import SnowballStemmer
from nltk.stem import LancasterStemmer

# %%
p_stemm=PorterStemmer()
s_stemm=SnowballStemmer(language='english')
lan_stemm=LancasterStemmer()

# %%
p_st=list(map(lambda x:p_stemm.stem(x),filter))
s_st=list(map(lambda x:s_stemm.stem(x),filter))
l_st=list(map(lambda x:lan_stemm.stem(x), filter))

# %%
pos=nltk.pos_tag(filter)
pos
# Out:
# [('listening', 'VBG'),
#  ('conversation', 'NN'),
#  ('doctor', 'NN'),
#  ('parents', 'NNS'),
#  ('10-year-old', 'JJ'),
#  ('oscar', 'NN'),
#  ('learns', 'VBZ'),
#  ('nobody', 'JJ'),
#  ('courage', 'NN'),
#  ('tell', 'VB'),
#  ('weeks', 'NNS'),
#  ('live', 'VBP'),
#  ('furious', 'JJ'),
#  ('refuses', 'NNS'),
#  ('speak', 'VBP'),
#  ('anyone', 'NN'),
#  ('except', 'IN'),
#  ('straight-talking', 'NN'),
#  ('rose', 'VBD'),
#  ('lady', 'JJ'),
#  ('pink', 'JJ'),
#  ('meets', 'NNS'),
#  ('hospital', 'JJ'),
#  ('stairs', 'NNS'),
#  ('christmas', 'NN'),
#  ('approaches', 'NNS'),
#  ('rose', 'VBD'),
#  ('uses', 'NNS'),
#  ('fantastical', 'JJ'),
#  ('experiences', 'NNS'),
#  ('professional', 'JJ'),
#  ('wrestler', 'NN'),
#  ('imagination', 'NN'),
#  ('wit', 'NN'),
#  ('charm', 'NN'),
#  ('allow', 'NN'),
#  ('oscar', 'NN'),
#  ('live', 'JJ'),
#  ('life', 'NN'),
#  ('love', 'IN'),
#  ('full', 'JJ'),
#  ('company', 'NN'),
#  ('friends', 'NNS'),
#  ('pop', 'VBP'),
#  ('corn', 'NN'),
#  ('einstein', 'NN'),
#  ('bacon', 'NN'),
#  ('childhood', 'NN'),
#  ('sweetheart', 'NN'),
#  ('peggy', 'VBZ'),
#  ('blue', 'JJ'),
#  ('brother', 'NN'),
#  ('sister', 'NN'),
#  ('past', 'IN'),
#  ('incestuous', 'JJ'),
#  ('relationship', 'NN'),
#  ('current', 'JJ'),
#  ('murderous', 'JJ'),
#  ('relationship', 'NN'),
#  ('murders', 'NNS'),
#  ('women', 'NNS'),
#  ('reject', 'VBP'),
#  ('murders', 'NNS'),
#  ('women', 'NNS'),
#  ('get', 'VBP'),
#  ('close', 'JJ'),
#  ('help', 'NN'),
#  ('unemployed', 'VBD'),
#  ('father', 'RB'),
#  ('make', 'VB'),
#  ('ends', 'NNS'),
#  ('meet', 'VB'),
#  ('edith', 'JJ'),
#  ('twin', 'NNS'),
#  ('sister', 'JJ'),
#  ('grace', 'NN'),
#  ('work', 'NN'),
#  ('seamstresses', 'NNS'),
#  ('invalid', 'JJ'),
#  ('grace', 'NN'),
#  ('falls', 'VBZ'),
#  ('prey', 'JJ'),
#  ('temptations', 'NNS'),
#  ('chinatown', 'VBP'),
#  ('opium', 'NN'),
#  ('becomes', 'VBZ'),
#  ('addict', 'JJ'),
#  ('condition', 'NN'),
#  ('worsened', 'VBD'),
#  ('misguided', 'JJ'),
#  ('physician', 'NN'),
#  ('prescribes', 'NNS'),
#  ('morphine', 'VBP'),
#  ('ease', 'NN'),
#  ('pain', 'NN'),
#  ('father', 'NN'),
#  ('strikes', 'NNS'),
#  ('oil', 'NN'),
#  ('family', 'NN'),
#  ('enjoys', 'VBZ'),
#  ('new', 'JJ'),
#  ('prosperity', 'NN'),
#  ('sisters', 'NNS'),
#  ('meet', 'RBR'),
#  ('eligible', 'JJ'),
#  ('jack', 'NN'),
#  ('herron', 'NN'),
#  ('fellow', 'JJ'),
#  ('oil', 'NN'),
#  ('prospector', 'NN'),
#  ('grace', 'NN'),
#  ("'s", 'POS'),
#  ('shock', 'NN'),
#  ('jack', 'NN'),
#  ('falls', 'VBZ'),
#  ('love', 'IN'),
#  ('edith', 'NN'),
#  ('jealousy', 'JJ'),
#  ('grace', 'NN'),
#  ('tells', 'NNS'),
#  ('jack', 'VBP'),
#  ('edith', 'JJ'),
#  ('drug', 'NN'),
#  ('problem', 'NN'),
#  ('hinting', 'VBG'),
#  ('sister', 'NN'),
#  ('soon', 'RB'),
#  ('need', 'MD'),
#  ('morphine', 'VB'),
#  ('grace', 'NN'),
#  ('arranges', 'NNS'),
#  ('dinner', 'VBP'),
#  ('chinatown', 'JJ'),
#  ('couple', 'NN'),
#  ('sister', 'NN'),
#  ('jack', 'NN'),
#  ('dance', 'NN'),
#  ('grace', 'NN'),
#  ('slips', 'VBZ'),
#  ('away', 'RB'),
#  ('opium', 'JJ'),
#  ('den', 'JJ'),
#  ('edith', 'NN'),
#  ('follows', 'VBZ'),
#  ('ends', 'VBZ'),
#  ('wrong', 'JJ'),
#  ('den', 'RB'),
#  ('arrested', 'VBN'),
#  ('ensuing', 'VBG'),
#  ('drug', 'NN'),
#  ('raid', 'NN'),
#  ('bails', 'NNS'),
#  ('jail', 'NN'),
#  ('edith', 'NN'),
#  ('takes', 'VBZ'),
#  ('angry', 'JJ'),
#  ('jack', 'NN'),
#  ('search', 'NN'),
#  ('grace', 'NN'),
#  ('stumbles', 'NNS'),
#  ('across', 'IN'),
#  ('half-conscious', 'JJ'),
#  ('body', 'NN'),
#  ('lying', 'VBG'),
#  ('street', 'NN'),
#  ('truth', 'NN'),
#  ('sisters', 'NNS'),
#  ('revealed', 'VBD'),
#  ('sending', 'VBG'),
#  ('grace', 'NN'),
#  ('sanitarium', 'JJ'),
#  ('country', 'NN'),
#  ('jack', 'NN'),
#  ('edith', 'NN'),
#  ('married', 'VBD'),
#  ('film', 'NN'),
#  ("'s", 'POS'),
#  ('title', 'NN'),
#  ('refers', 'NNS'),
#  ('un-recovered', 'JJ'),
#  ('bodies', 'NNS'),
#  ('ground', 'NN'),
#  ('zero', 'NN'),
#  ('also', 'RB'),
#  ('state', 'NN'),
#  ('nation', 'NN'),
#  ('large', 'JJ'),
#  ('set', 'VBN'),
#  ('hallucinatory', 'JJ'),
#  ('period', 'NN'),
#  ('time', 'NN'),
#  ('september', 'VB'),
#  ('11', 'CD'),
#  ('halloween', 'JJ'),
#  ('2001', 'CD'),
#  ('unrecovered', 'JJ'),
#  ('examines', 'NNS'),
#  ('effect', 'NN'),
#  ('terror', 'NN'),
#  ('average', 'NN'),
#  ('mind', 'NN'),
#  ('way', 'NN'),
#  ('state', 'NN'),
#  ('heightened', 'VBD'),
#  ('anxiety', 'NN'),
#  ('and/or', 'NN'),
#  ('alertness', 'NN'),
#  ('cause', 'NN'),
#  ('average', 'JJ'),
#  ('person', 'NN'),
#  ('make', 'VBP'),
#  ('sort', 'NN'),
#  ('imaginative', 'JJ'),
#  ('connections', 'NNS'),
#  ('normally', 'RB'),
#  ('made', 'VBD'),
#  ('artists', 'NNS'),
#  ('conspiracy', 'JJ'),
#  ('theorists-both', 'JJ'),
#  ('figure', 'NN'),
#  ('prominently', 'RB'),
#  ('film', 'NN'),
#  ('unrecovered', 'JJ'),
#  ('explores', 'VBZ'),
#  ('way', 'NN'),
#  ('irony', 'NN'),
#  ('empathy', 'JJ'),
#  ('paranoia', 'NN'),
#  ('relate', 'VB'),
#  ('one', 'CD'),
#  ('another', 'DT'),
#  ('wake', 'NN'),
#  ('9/11', 'CD'),
#  ('quality', 'NN'),
#  ('control', 'NN'),
#  ('consists', 'VBZ'),
#  ('series', 'NN'),
#  ('16mm', 'CD'),
#  ('single', 'JJ'),
#  ('take', 'NN'),
#  ('shots', 'NNS'),
#  ('filmed', 'VBD'),
#  ('summer', 'NN'),
#  ('2010', 'CD'),
#  ('two', 'CD'),
#  ('day', 'NN'),
#  ('period', 'NN'),
#  ('dry', 'JJ'),
#  ('cleaners', 'NNS'),
#  ('facility', 'NN'),
#  ('pritchard', 'VBP'),
#  ('alabama', 'NN'),
#  ('near', 'IN'),
#  ('mobile', 'JJ'),
#  ('quality', 'NN'),
#  ('control', 'NN'),
#  ('exhibits', 'VBZ'),
#  ('acts', 'NNS'),
#  ('well', 'RB'),
#  ('conditions', 'NNS'),
#  ('around', 'IN'),
#  ('labor', 'NN'),
#  ('showcases', 'NNS'),
#  ('everson', 'VBP'),
#  ("'s", 'POS'),
#  ('words', 'NNS'),
#  ('``', '``'),
#  ('fine', 'JJ'),
#  ('folks', 'NNS'),
#  ('alabama', 'IN'),
#  ('producing', 'VBG'),
#  ('superior', 'JJ'),
#  ('product', 'NN'),
#  ("''", "''"),
#  ('similar', 'JJ'),
#  ('stylistically', 'RB'),
#  ('form', 'JJ'),
#  ('rhythm', 'NN'),
#  ('certain', 'JJ'),
#  ('scenarios', 'NNS'),
#  ('everson', 'VBP'),
#  ("'s", 'POS'),
#  ('award-winning', 'JJ'),
#  ('critically', 'RB'),
#  ('acclaimed', 'VBN'),
#  ('previous', 'JJ'),
#  ('films', 'NNS'),
#  ('including', 'VBG'),
#  ('erie', 'NN'),
#  ('iffr', 'NN'),
#  ('2010', 'CD'),
#  ('thematic', 'JJ'),
#  ('concerns', 'NNS'),
#  ('several', 'JJ'),
#  ('short', 'JJ'),
#  ('form', 'NN'),
#  ('works', 'VBZ'),
#  ('follow', 'JJ'),
#  ('daily', 'JJ'),
#  ('quotidian', 'JJ'),
#  ('tasks', 'NNS'),
#  ('workers', 'NNS'),
#  ('rest', 'VBP'),
#  ('motion', 'NN'),
#  ('oblique', 'NN'),
#  ('sequel', 'NN'),
#  ('ten', 'CD'),
#  ('years', 'NNS'),
#  ('hence', 'RB'),
#  ('everson', 'VBP'),
#  ("'s", 'POS'),
#  ('creative', 'JJ'),
#  ('capital', 'NN'),
#  ('granted', 'VBN'),
#  ('project', 'NN'),
#  ('week', 'NN'),
#  ('hole', 'NN'),
#  ('2001', 'CD'),
#  ('focused', 'VBD'),
#  ('employee', 'NN'),
#  ("'s", 'POS'),
#  ('adjustment', 'NN'),
#  ('materials', 'NNS'),
#  ('time', 'NN'),
#  ('space', 'NN'),
#  ('personnel', 'NNS'),
#  ('quality', 'NN'),
#  ('control', 'NN'),
#  ('consists', 'VBZ'),
#  ('series', 'NN'),
#  ('16mm', 'CD'),
#  ('single', 'JJ'),
#  ('take', 'NN'),
#  ('shots', 'NNS'),
#  ('filmed', 'VBD'),
#  ('two', 'CD'),
#  ('day', 'NN'),
#  ('period', 'NN'),
#  ('summer', 'NN'),
#  ('2010', 'CD'),
#  ('dry', 'NN'),
#  ('cleaners', 'NNS'),
#  ('facility', 'NN'),
#  ('pritchard', 'VBP'),
#  ('alabama', 'NN'),
#  ('near', 'IN'),
#  ('mobile', 'JJ'),
#  ('quality', 'NN'),
#  ('control', 'NN'),
#  ('exhibits', 'VBZ'),
#  ('acts', 'NNS'),
#  ('well', 'RB'),
#  ('conditions', 'NNS'),
#  ('around', 'IN'),
#  ('labor', 'NN'),
#  ('similar', 'JJ'),
#  ('stylistically', 'RB'),
#  ('form', 'JJ'),
#  ('rhythm', 'NN'),
#  ('certain', 'JJ'),
#  ('scenarios', 'NNS'),
#  ('everson', 'VBP'),
#  ("'s", 'POS'),
#  ('award-winning', 'JJ'),
#  ('critically', 'RB'),
#  ('acclaimed', 'VBN'),
#  ('previous', 'JJ'),
#  ('films', 'NNS'),
#  ('including', 'VBG'),
#  ('erie', 'NN'),
#  ('iffr', 'NN'),
#  ('2010', 'CD'),
#  ('thematic', 'JJ'),
#  ('concerns', 'NNS'),
#  ('several', 'JJ'),
#  ('short', 'JJ'),
#  ('form', 'NN'),
#  ('works', 'VBZ'),
#  ('follow', 'JJ'),
#  ('daily', 'JJ'),
#  ('quotidian', 'JJ'),
#  ('tasks', 'NNS'),
#  ('workers', 'NNS'),
#  ('rest', 'VBP'),
#  ('motion', 'NN'),
#  ('including', 'VBG'),
#  ('factory', 'NN'),
#  ('routine', 'NN'),
#  ('captured', 'VBN'),
#  ('short', 'JJ'),
#  ('film', 'NN'),
#  ('week', 'NN'),
#  ('hole', 'NN'),
#  ('2001', 'CD'),
#  ('focused', 'VBD'),
#  ('employee', 'NN'),
#  ("'s", 'POS'),
#  ('adjustment', 'NN'),
#  ('materials', 'NNS'),
#  ('time', 'NN'),
#  ('space', 'NN'),
#  ('personnel', 'NNS'),
#  ('principal', 'JJ'),
#  ('cast', 'VBD'),
#  ('includes', 'VBZ'),
#  ('shay', 'JJ'),
#  ('wright', 'NN'),
#  ('annette', 'NN'),
#  ('speight', 'VBD'),
#  ('tough', 'JJ'),
#  ('economic', 'JJ'),
#  ('times', 'NNS'),
#  ('max', 'VBP'),
#  ('joey', 'JJ'),
#  ('run', 'NN'),
#  ('ideas', 'NNS'),
#  ('discover', 'RB'),
#  ('senior', 'JJ'),
#  ('housing', 'NN'),
#  ('cheap', 'JJ'),
#  ('max', 'NN'),
#  ("'s", 'POS'),
#  ('aunt', 'NN'),
#  ('kicked', 'VBD'),
#  ('bucket', 'NN'),
#  ('one', 'CD'),
#  ('knows', 'VBZ'),
#  ('yet', 'RB'),
#  ('hilarious', 'JJ'),
#  ('series', 'NN'),
#  ('always', 'RB'),
#  ('keeps', 'VBZ'),
#  ('toes', 'NNS'),
#  ('two', 'CD'),
#  ('friends', 'NNS'),
#  ('take', 'VBP'),
#  ('us', 'PRP'),
#  ('cross-dressing', 'JJ'),
#  ('desperate', 'JJ'),
#  ('endearing', 'NN'),
#  ('ride', 'NN'),
#  ('broke', 'VBD'),
#  ('four', 'CD'),
#  ('high', 'JJ'),
#  ('school', 'NN'),
#  ('students', 'NNS'),
#  ('embark', 'VBP'),
#  ('terrifying', 'VBG'),
#  ('journey', 'NN'),
#  ('shadowview', 'NN'),
#  ('manor', 'VBD'),
#  ('2', 'CD'),
#  ('years', 'NNS'),
#  ('horrifying', 'VBG'),
#  ('séance', 'NN'),
#  ('gone', 'VBN'),
#  ('wrong', 'JJ'),
#  ('intern', 'JJ'),
#  ('raven', 'VBN'),
#  ('decides', 'NNS'),
#  ('reconnect', 'VBP'),
#  ('elementary', 'JJ'),
#  ('school', 'NN'),
#  ('friends', 'NNS'),
#  ('kota', 'VBP'),
#  ('william', 'NN'),
#  ('jessica', 'NN'),
#  ('bringing', 'VBG'),
#  ('new', 'JJ'),
#  ('workplace', 'NN'),
#  ('shadowview', 'NN'),
#  ('manor', 'JJ'),
#  ('bit', 'NN'),
#  ('paranormal', 'JJ'),
#  ('investigating', 'VBG'),
#  ('hearing', 'VBG'),
#  ('forbidden', 'JJ'),
#  ('secrets', 'NNS'),
#  ('night', 'NN'),
#  ('janitor', 'NN'),
#  ('sends', 'VBZ'),
#  ('dark', 'JJ'),
#  ('descending', 'VBG'),
#  ('spiral', 'JJ'),
#  ('terror', 'NN'),
#  ('tom', 'NN'),
#  ('beacham', 'NN'),
#  ('explores', 'VBZ'),
#  ('ghana', 'JJ'),
#  ('director', 'NN'),
#  ('photography', 'NN'),
#  ('alex', 'JJ'),
#  ('holberton', 'NN'),
#  ('search', 'NN'),
#  ('spirits', 'NNS'),
#  ('film', 'NN'),
#  ('looks', 'VBZ'),
#  ('overlap', 'IN'),
#  ('spirit', 'JJ'),
#  ('world', 'NN'),
#  ('physical', 'JJ'),
#  ('world', 'NN'),
#  ('voodoo', 'NN'),
#  ('witchcraft', 'NN'),
#  ('power', 'NN'),
#  ('holy', 'NN'),
#  ('spirit', 'NN'),
#  ('magic', 'JJ'),
#  ('meet', 'NN'),
#  ('royal', 'JJ'),
#  ('family', 'NN'),
#  ('members', 'NNS'),
#  ('magicians', 'NNS'),
#  ('voodoo', 'JJ'),
#  ('priests', 'NNS'),
#  ('well', 'RB'),
#  ('getting', 'VBG'),
#  ('rare', 'JJ'),
#  ('footage', 'NN'),
#  ('full', 'JJ'),
#  ('voodoo', 'NN'),
#  ('ceremony', 'NN'),
#  ('danny', 'NN'),
#  ('dying', 'VBG'),
#  ('aids', 'NNS'),
#  ('returns', 'VBZ'),
#  ('home', 'NN'),
#  ('last', 'JJ'),
#  ('months', 'NNS'),
#  ('always', 'RB'),
#  ('close', 'RB'),
#  ('mother', 'JJ'),
#  ('share', 'NN'),
#  ('moments', 'NNS'),
#  ('openness', 'IN'),
#  ('tend', 'VBP'),
#  ('shut', 'JJ'),
#  ('danny', 'NN'),
#  ("'s", 'POS'),
#  ('father', 'NN'),
#  ('sister', 'NN'),
#  ('sister', 'NN'),
#  ("'s", 'POS'),
#  ('breast', 'NN'),
#  ('cancer', 'NN'),
#  ('diagnosis', 'NN'),
#  ('brother', 'NN'),
#  ("'s", 'POS'),
#  ('need', 'JJ'),
#  ('take', 'VB'),
#  ('action', 'NN'),
#  ('highlighting', 'VBG'),
#  ('events', 'NNS'),
#  ('took', 'VBD'),
#  ('place', 'NN'),
#  ('franke', 'NN'),
#  ("'s", 'POS'),
#  ('participation', 'NN'),
#  ('susan', 'FW'),
#  ('g.', 'JJ'),
#  ('komen', 'NNS'),
#  ('3-day', 'JJ'),
#  ('walk', 'NN'),
#  ('including', 'VBG'),
#  ('training', 'VBG'),
#  ('fund-raising', 'JJ'),
#  ('events', 'NNS'),
#  ('six', 'CD'),
#  ('months', 'NNS'),
#  ('preceding', 'VBG'),
#  ('walk', 'NN'),
#  ('includes', 'VBZ'),
#  ('numerous', 'JJ'),
#  ('interviews', 'NNS'),
#  ('breast', 'NN'),
#  ('cancer', 'NN'),
#  ('survivors', 'NNS'),
#  ('share', 'NN'),
#  ('wealth', 'NN'),
#  ('experience', 'NN'),
#  ('viewer', 'NN'),
#  ('also', 'RB'),
#  ('included', 'VBD'),
#  ('appearances', 'NNS'),
#  ('local', 'JJ'),
#  ('celebrities', 'NNS'),
#  ('athletes', 'VBZ'),
#  ('musical', 'JJ'),
#  ('artists', 'NNS'),
#  ('well', 'RB'),
#  ('informative', 'JJ'),
#  ('interviews', 'NNS'),
#  ('health', 'NN'),
#  ('care', 'NN'),
#  ('professionals', 'NNS'),
#  ('explain', 'VBP'),
#  ('should', 'MD'),
#  ('know', 'VB'),
#  ('dealing', 'VBG'),
#  ('illness', 'JJ'),
#  ('film', 'NN'),
#  ('doctor', 'NN'),
#  ('should', 'MD'),
#  ('given', 'VBN'),
#  ('sister', 'VB'),
#  ('left', 'JJ'),
#  ('office', 'NN'),
#  ('fateful', 'JJ'),
#  ('day', 'NN'),
#  ('made', 'VBD'),
#  ('film', 'NN'),
#  ('sister', 'NN'),
#  ('sisters', 'NNS'),
#  ('...', ':'),
#  ('would', 'MD'),
#  ('always', 'RB'),
#  ('remember', 'VB'),
#  ('``', '``'),
#  ('alone', 'RB'),
#  ("''", "''"),
#  ('photographer', 'CC'),
#  ('sailing', 'VBG'),
#  ('wife', 'NN'),
#  ('sister', 'JJ'),
#  ('nympho-maniacal', 'JJ'),
#  ('model', 'NN'),
#  ('leaves', 'VBZ'),
#  ('three', 'CD'),
#  ('women', 'NNS'),
#  ('alone', 'RB'),
#  ('get', 'VB'),
#  ('part', 'NN'),
#  ('boat', 'NN'),
#  ('mysterious', 'JJ'),
#  ('man', 'NN'),
#  ('shows', 'NNS'),
#  ('might', 'MD'),
#  ('escaped', 'VB'),
#  ('criminal', 'JJ'),
#  ('police', 'NNS'),
#  ('searching', 'VBG'),
#  ("n't", 'RB'),
#  ('alarm', 'VB'),
#  ('three', 'CD'),
#  ('women', 'NNS'),
#  ('much', 'RB'),
#  ('rapidly', 'RB'),
#  ('seduces', 'NNS'),
#  ('three', 'CD'),
#  ('amanda', 'NNS'),
#  ('wingfield', 'VBP'),
#  ('dominates', 'VBZ'),
#  ('children', 'NNS'),
#  ('faded', 'VBD'),
#  ('gentility', 'NN'),
#  ('exaggerated', 'JJ'),
#  ('tales', 'NNS'),
#  ('southern', 'JJ'),
#  ('belle', 'IN'),
#  ('past', 'JJ'),
#  ('son', 'NN'),
#  ('plans', 'NNS'),
#  ('escape', 'VBP'),
#  ('daughter', 'NN'),
#  ('withdraws', 'NN'),
#  ('dream', 'NN'),
#  ('world', 'NN'),
#  ('``', '``'),
#  ('gentleman', 'JJ'),
#  ('caller', 'NN'),
#  ("''", "''"),
#  ('appears', 'VBZ'),
#  ('things', 'NNS'),
#  ('move', 'VBP'),
#  ('crisis', 'NN'),
#  ('point', 'NN'),
#  ('amanda', 'NN'),
#  ('faced', 'VBD'),
#  ('dilemma', 'JJ'),
#  ('dependent', 'JJ'),
#  ('life', 'NN'),
#  ('remaining', 'VBG'),
#  ('years', 'NNS'),
#  ('importantly', 'RB'),
#  ('dependent', 'JJ'),
#  ('daughter', 'NN'),
#  ('laura', 'NN'),
#  ('amanda', 'NN'),
#  ('struggles', 'VBZ'),
#  ('use', 'VBP'),
#  ('means', 'NNS'),
#  ('disposable', 'JJ'),
#  ('secure', 'JJ'),
#  ('future', 'NN'),
#  ('frightened', 'VBD'),
#  ('fragile', 'JJ'),
#  ('``', '``'),
#  ('spinster', 'NN'),
#  ("''", "''"),
#  ('daughter', 'NN'),
#  ('simon', 'NN'),
#  ("'s", 'POS'),
#  ('world', 'NN'),
#  ('turned', 'VBD'),
#  ('upside', 'JJ'),
#  ('little', 'JJ'),
#  ('girl', 'JJ'),
#  ('katie', 'NN'),
#  ('abducted', 'VBD'),
#  ('family', 'NN'),
#  ('day', 'NN'),
#  ('weeks', 'NNS'),
#  ('searching', 'VBG'),
#  ('appeals', 'NNS'),
#  ('simon', 'JJ'),
#  ('decides', 'NNS'),
#  ('punish', 'JJ'),
#  ('offering', 'NN'),
#  ('young', 'JJ'),
#  ('prostitute', 'NN'),
#  ('mounting', 'NN'),
#  ('debts', 'NNS'),
#  ('life', 'NN'),
#  ('changing', 'VBG'),
#  ('money', 'NN'),
#  ('end', 'NN'),
#  ('life', 'NN'),
#  ('frankie', 'NN'),
#  ('reno', 'VBP'),
#  ('child', 'NN'),
#  ('star', 'NN'),
#  ('tv', 'NN'),
#  ('show', 'NN'),
#  ('thirty', 'CD'),
#  ('years', 'NNS'),
#  ('ago', 'RB'),
#  ("'s", 'POS'),
#  ('busy', 'JJ'),
#  ('making', 'VBG'),
#  ('ends', 'JJ'),
#  ('meet', 'NN'),
#  ('running', 'VBG'),
#  ('``', '``'),
#  ('babylon', 'NN'),
#  ('vista', 'NN'),
#  ("''", "''"),
#  ('hollywood', 'NN'),
#  ('apartment', 'NN'),
#  ('inhabited', 'VBD'),
#  ('has-beens', 'JJ'),
#  ('wannabees', 'NNS'),
#  ('stories', 'NNS'),
#  ('rent', 'NN'),
#  ('payments', 'NNS'),
#  ('frankie', 'VBP'),
#  ('slowly', 'RB'),
#  ('finds', 'VBZ'),
#  ('getting', 'VBG'),
#  ('sucked', 'VBN'),
#  ('bizarre', 'JJ'),
#  ('world', 'NN'),
#  ('dysfunctional', 'JJ'),
#  ('tenants', 'NNS'),
#  ('story', 'NN'),
#  ('castle', 'JJ'),
#  ('family', 'NN'),
#  ('norbert', 'JJ'),
#  ('salburg-falkenstein', 'JJ'),
#  ('commander', 'NN'),
#  ('knights', 'NNS'),
#  ('malte', 'VBP'),
#  ('österreich', 'JJ'),
#  ('bohemia', 'NN'),
#  ('married', 'VBD'),
#  ('daughter', 'NN'),
#  ('naval', 'JJ'),
#  ('commander', 'NN'),
#  ('sweden', 'NN'),
#  ('able', 'JJ'),
#  ('restore', 'NN'),
#  ('family', 'NN'),
#  ('property', 'NN'),
#  ('correctly', 'RB'),
#  ('help', 'VBZ'),
#  ('wagnerian', 'JJ'),
#  ('opera', 'NN'),
#  ('singer', 'NN'),
#  ('sings', 'NNS'),
#  ('welsh', 'VBP'),
#  ('wagnerian', 'JJ'),
#  ('music', 'NN'),
#  ('video', 'NN'),
#  ('one', 'CD'),
#  ('series', 'NN'),
#  ('nobility', 'NN'),
#  ('deutschland', 'VBP'),
#  ('österreich', 'NNP'),
#  ('live', 'VBP'),
#  ('various', 'JJ'),
#  ('castles', 'NNS'),
#  ('lively', 'RB'),
#  ('fun', 'VBP'),
#  ('commentary', 'JJ'),
#  ('tv', 'NN'),
#  ('hosts', 'NNS'),
#  ('one', 'CD'),
#  ('descendant', 'NN'),
#  ('great', 'JJ'),
#  ('hapsburg', 'NN'),
#  ('dynasty', 'JJ'),
#  ('road', 'NN'),
#  ('milk', 'NN'),
#  ('narrates', 'VBZ'),
#  ('existential', 'JJ'),
#  ('drama', 'NN'),
#  ('tones', 'NNS'),
#  ('story', 'NN'),
#  ('man', 'NN'),
#  ('searching', 'VBG'),
#  ('lost', 'VBN'),
#  ('time', 'NN'),
#  ('traveling', 'VBG'),
#  ('across', 'IN'),
#  ('roads', 'NNS'),
#  ('brazil', 'VBP'),
#  ("'s", 'POS'),
#  ('countryside', 'NN'),
#  ('making', 'NN'),
#  ('way', 'NN'),
#  ('back', 'RB'),
#  ('homeland', 'NN'),
#  ('journey', 'NN'),
#  ('find', 'VB'),
#  ('way', 'NN'),
#  ('sign', 'NN'),
#  ('past', 'IN'),
#  ('remake', 'JJ'),
#  ('life', 'NN'),
#  ('show', 'VBP'),
#  ('path', 'JJ'),
#  ('salvation', 'NN'),
#  ('threshold', 'VBD'),
#  ('reason', 'NN'),
#  ('madness', 'NN'),
#  ('salvation', 'NN'),
#  ('death', 'NN'),
#  ('gang', 'NN'),
#  ('unemployed', 'JJ'),
#  ('itinerant', 'NN'),
#  ('musicians', 'NNS'),
#  ('play', 'VBP'),
#  ('south', 'RB'),
#  ('stockholm', 'JJ'),
#  ('get', 'VB'),
#  ('chance', 'NN'),
#  ('orchestra', 'JJ'),
#  ('dance', 'NN'),
#  ('restaurant', 'NN'),
#  ('goes', 'VBZ'),
#  ('well', 'RB'),
#  ('female', 'JJ'),
#  ('owner', 'NN'),
#  ('falls', 'VBZ'),
#  ('love', 'VBP'),
#  ('one', 'CD'),
#  ('committee', 'NN'),
#  ('investigating', 'VBG'),
#  ('tv', 'NN'),
#  ("'s", 'POS'),
#  ('first', 'JJ'),
#  ('uncensored', 'JJ'),
#  ('network', 'NN'),
#  ('examines', 'NNS'),
#  ('typical', 'JJ'),
#  ('day', 'NN'),
#  ("'s", 'POS'),
#  ('programming', 'NN'),
#  ('includes', 'VBZ'),
#  ('shows', 'NNS'),
#  ('commercials', 'NNS'),
#  ('news', 'NN'),
#  ('programs', 'NNS'),
#  ('name', 'VBP'),
#  ('discover', 'RB'),
#  ('surely', 'RB'),
#  ('crack', 'VBP'),
#  ('outrageous', 'JJ'),
#  ('irreverent', 'NN'),
#  ('spoof', 'NN'),
#  ('television', 'NN'),
#  ('launched', 'VBD'),
#  ('careers', 'NNS'),
#  ('greatest', 'JJS'),
#  ('comedians', 'NNS'),
#  ('time', 'NN'),
#  ('1976', 'CD'),
#  ('film', 'NN'),
#  ('tries', 'NNS'),
#  ('predict', 'VBP'),
#  ('american', 'JJ'),
#  ('television', 'NN'),
#  ('like', 'IN'),
#  ('year', 'NN'),
#  ('1985', 'CD'),
#  ('tunnelvision', 'NN'),
#  ('america', 'NN'),
#  ("'s", 'POS'),
#  ('first', 'JJ'),
#  ('``', '``'),
#  ('uncensored', 'JJ'),
#  ('free', 'JJ'),
#  ("''", "''"),
#  ('television', 'NN'),
#  ('network', 'NN'),
#  ('although', 'IN'),
#  ('wildly', 'RB'),
#  ('popular', 'JJ'),
#  ('also', 'RB'),
#  ('blamed', 'VBD'),
#  ('increased', 'JJ'),
#  ('crime', 'NN'),
#  ('unemployment', 'NN'),
#  ('christian', 'JJ'),
#  ('a.', 'NN'),
#  ('broder', 'NN'),
#  ('president', 'NN'),
#  ('founder', 'NN'),
#  ('tunnelvision', 'NN'),
#  ('called', 'VBN'),
#  ('defend', 'NN'),
#  ('network', 'NN'),
#  ('front', 'JJ'),
#  ('senate', 'JJ'),
#  ('sub-committee', 'JJ'),
#  ('sub-committee', 'NN'),
#  ('decides', 'NNS'),
#  ('view', 'VBP'),
#  ('excerpts', 'VBP'),
#  ('``', '``'),
#  ('typical', 'JJ'),
#  ("''", "''"),
#  ('day', 'NN'),
#  ('tunnelvision', 'NN'),
#  ('broadcasting', 'NN'),
#  ('follows', 'VBZ'),
#  ('series', 'NN'),
#  ('brief', 'NN'),
#  ('skits', 'VBZ'),
#  ('lampooning', 'VBG'),
#  ('television', 'NN'),
#  ('including', 'VBG'),
#  ('cop', 'NN'),
#  ('shows', 'NNS'),
#  ('news', 'NN'),
#  ('broadcasts', 'NNS'),
#  ('situation', 'NN'),
#  ('comedies', 'NNS'),
#  ('course', 'NN'),
#  ('commercials', 'NNS'),
#  ('wedded', 'VBD'),
#  ('bliss', 'JJ'),
#  ('explores', 'NNS'),
#  ('perception', 'VBP'),
#  ('one', 'CD'),
#  ("'s", 'POS'),
#  ('wedding', 'VBG'),
#  ('one', 'CD'),
#  ("'s", 'POS'),
#  ('newly', 'RB'),
#  ('wedded', 'VBN'),
#  ('life', 'NN'),
#  ('perfect', 'JJ'),
#  ('romantic', 'JJ'),
#  ('time', 'NN'),
#  ('one', 'CD'),
#  ("'s", 'POS'),
#  ('life', 'NN'),
#  ('reality', 'NN'),
#  ('many', 'JJ'),
#  ('people', 'NNS'),
#  ('two', 'CD'),
#  ('families', 'NNS'),
#  ('coming', 'VBG'),
#  ('together', 'RB'),
#  ('almost', 'RB'),
#  ('always', 'RB'),
#  ('``', '``'),
#  ('miscommunication', 'NN'),
#  ("''", "''"),
#  ('always', 'RB'),
#  ('start', 'VB'),
#  ('small', 'JJ'),
#  ('become', 'NN'),
#  ('bigger', 'JJR'),
#  ('baggage', 'NN'),
#  ('becomes', 'VBZ'),
#  ('big', 'JJ'),
#  ('distraction', 'NN'),
#  ('new', 'JJ'),
#  ('couple', 'NN'),
#  ...]

# %%
vocab=set(filter)
vocab
# Out:
# {'hatboro',
#  'jitli',
#  '3:59',
#  'away.so',
#  'ass-blowing',
#  'joelma',
#  'legendarily',
#  'joey-five',
#  'work/karma',
#  'beckermann',
#  'sabaoon',
#  'piershale',
#  'unfolds.in',
#  "'dad",
#  'south-american',
#  'gullets',
#  'associates',
#  'till',
#  'spendabel',
#  'lowery',
#  'burocracy',
#  'paiting',
#  'silencing',
#  'hezekiah',
#  'back.he',
#  'neuron',
#  'ranchos',
#  'mondragon',
#  'roves',
#  'pasión',
#  'thebes',
#  'skeates',
#  'devos',
#  'hardayal',
#  'kono',
#  'demarcated',
#  'stringent',
#  'bosphorous',
#  'placer',
#  'twenty-seven-year-old',
#  'veranda',
#  'relatedness',
#  'commissioning',
#  'biyuda',
#  'erleben',
#  'guests',
#  'potato-crusted',
#  'neil',
#  'process',
#  'vedantan',
#  'danseurs-citoyens',
#  'sont',
#  'haraway',
#  'valorise',
#  'touchet',
#  'one-night',
#  'founds',
#  'kinta',
#  'korszerutlen',
#  'non-indigenous',
#  'odb',
#  'attackers',
#  'sells',
#  'traitors',
#  'event-filled',
#  'cascading',
#  'out-do',
#  'rosey',
#  'forsberg',
#  'waffle',
#  'jang-shin',
#  'dissing',
#  'éric',
#  'substantiate',
#  "nell'isola",
#  'poncia',
#  'oppugnant',
#  'mustapha',
#  '1948-as',
#  'baden',
#  'demeanor',
#  'forbade',
#  'surveying',
#  'ghaydaa',
#  'often-sanitized',
#  'dalí',
#  'astronňmica',
#  'roriz.at',
#  'drink.for',
#  'petrenko',
#  'chulbul',
#  'dr.rajiv',
#  "'customer",
#  'civility',
#  'vojtech',
#  'lonesome',
#  'hlatswayo',
#  'burr',
#  'miraj',
#  'titillations',
#  'haug',
#  'ambiguities',
#  'never-before-attempted',
#  'alkoholischer',
#  'hommes',
#  'empowerments',
#  'paillasse',
#  'intrusions',
#  'too.relax',
#  'labor-intensive',
#  'semon',
#  'elicia',
#  'hammered',
#  'waco',
#  'prominant',
#  'mundae',
#  'memorials',
#  'maliki',
#  'sandstone',
#  '25cent',
#  'jolting',
#  'burmester',
#  'gezim',
#  'non-judgmental',
#  'pôles',
#  'slashing',
#  'collects',
#  'pičges',
#  'one-minute',
#  'menschen',
#  'pegasus',
#  'listen',
#  'ouen',
#  "'spiritual",
#  "'agent",
#  'velankanni',
#  'geriatric',
#  '16:1-4',
#  'brigadiers-',
#  'achingly',
#  'bedford',
#  'stupak',
#  'histories',
#  'win-an',
#  'alexander',
#  'toptown',
#  'grrlz',
#  'firebrand',
#  'sketchs',
#  'bernhardt',
#  '21th',
#  'great-great-grandchildren',
#  'grivelli',
#  'tatya',
#  'grandparental',
#  'glimmering',
#  'byun',
#  'khone',
#  'pontian',
#  'long-absent',
#  'lanterns',
#  'arabella',
#  'thunder',
#  'cardoza',
#  'shrinking',
#  'kooky',
#  'winepires',
#  'cassettes',
#  'maxim',
#  'daughters',
#  'scifi',
#  'inconvenience',
#  'dispose',
#  'mid-point',
#  'advertisers',
#  'kusturica',
#  'indians',
#  "'starving",
#  'zhela',
#  'co-education',
#  'convertino',
#  'blignauts',
#  'near-insurmountable',
#  'moonlights',
#  'shellers',
#  'cavalo',
#  'eles',
#  'leading-edge',
#  'pucker',
#  'curveball',
#  'toxic-waste',
#  'reexamines',
#  'barroco',
#  'flatlined',
#  'infancy',
#  '7-years',
#  'kasane',
#  'karpovsky',
#  'idgie',
#  'duelists',
#  'beautifully',
#  'follies',
#  'dali',
#  'sewage',
#  'marie-paule',
#  'typified',
#  'annmarie',
#  'side',
#  'survivalists',
#  'newly-produced',
#  'vengeance',
#  'honest-seeming',
#  'morti',
#  'yeon',
#  'sfalcin',
#  'morett',
#  'lolita',
#  'mesmerized',
#  'accruing',
#  'factually',
#  'intense-looking',
#  'holt',
#  'residencies',
#  'petre',
#  'unmarino',
#  'un-phased',
#  'thembisile',
#  '2012-2016',
#  'silky',
#  'nia',
#  'laos',
#  'tidings',
#  'kaddafi',
#  'orfana',
#  "d'inattention",
#  'buckle',
#  'faubion',
#  'romanticized',
#  'tatjana',
#  'velveteen',
#  'history-',
#  'emphasize',
#  'aidan',
#  "'vermin",
#  'barak',
#  'yun-hee',
#  'nicolas',
#  'agioupa',
#  'shelmikedmu',
#  'karnaphuli',
#  'blurs',
#  'seductor',
#  'ensi',
#  'geshe',
#  'lowers',
#  'haglund',
#  'ardentes',
#  'squall',
#  'subsided',
#  'thunska',
#  'catholics',
#  'smuggling',
#  "'impact",
#  'hardheaded',
#  'jhansi',
#  'ghorrat',
#  'hardinger',
#  'hurra',
#  'rachtman',
#  'throbs',
#  'risers',
#  'lawyer/landlord',
#  'pros',
#  'bail',
#  'creativitŕ',
#  'kragh-jacobsen',
#  'barstow',
#  'orphange',
#  'dogtown',
#  'studies',
#  'elevator',
#  'chambleu',
#  'aktoreve',
#  'jostling',
#  'kurohane',
#  'levien',
#  'ricardo',
#  'stewardess',
#  'unknown-despite',
#  'roerich',
#  'verbringt',
#  'de-facto',
#  'navision',
#  'recommendations',
#  'courtesy',
#  'ruzicka',
#  'ever-tricky',
#  'chaperons',
#  'stet',
#  'indienne',
#  'govern',
#  'aquifer',
#  'tv-project',
#  'weigelt',
#  'kumi',
#  'adhesion',
#  'inroads',
#  'granat',
#  'aural',
#  'varieta',
#  'sd',
#  'marche',
#  'naziregimes',
#  'hiding-place',
#  'warhol',
#  'itthon',
#  'roel',
#  'martino',
#  'martindale',
#  'regnare',
#  'precipitated',
#  'harue',
#  'telegraphist',
#  'ex-freund',
#  'quilles',
#  'kinkaids',
#  'meddling',
#  'long-overdue',
#  'homage',
#  'non-sentimental',
#  'april-june',
#  "d'assister",
#  'geektastic',
#  'embankment',
#  'rigoberta',
#  'januzczak',
#  'asprey',
#  'debit-ridden',
#  'sent-down',
#  'dig',
#  'cyborgs',
#  'kemmer',
#  'ex-preacher',
#  'lombardo',
#  'jamaram',
#  "'obnoxious",
#  'hamlet',
#  'actress',
#  'anthropometries',
#  'champion/businessman',
#  'manobo',
#  'transformation',
#  'bacall',
#  'bidwill',
#  'jul',
#  'molander',
#  'kenna',
#  'y2j',
#  'navarra',
#  'nalacharitham',
#  'three-season',
#  'renewal-aleut',
#  'outil',
#  'lucknow',
#  'two',
#  'ghosla',
#  'mikey',
#  'fighting-stick',
#  'anapylaxis',
#  'jignesh',
#  'parlays',
#  'dad',
#  'dwarf',
#  'eliot',
#  'grabbers',
#  'pathetically',
#  'astroland',
#  'slay',
#  'rosenbaum',
#  'smartened',
#  'vandalous',
#  'novy',
#  'weatherbee',
#  'do-gooding',
#  'participated-in',
#  'canales',
#  'witherings',
#  '1942',
#  'tabaski',
#  'ulmen',
#  'losier',
#  'voskovec',
#  'zigeunerbaron',
#  'psycho-therapy',
#  'after-the',
#  'archdutchess',
#  'cows',
#  'accountable',
#  'refreshes',
#  'urine',
#  'swingers',
#  'nis',
#  'chthonic',
#  'latent',
#  'height',
#  'addict-savant',
#  'menoka',
#  'alcuar',
#  '950bc',
#  'fittses',
#  'batsman',
#  'washout',
#  'sofi',
#  'fears',
#  'susanne',
#  'interloper',
#  'guidée',
#  'sith',
#  'nazs',
#  'tycoons',
#  'ganesh',
#  'semi-talented',
#  'although',
#  'babylone',
#  'caprure',
#  'dog-owners',
#  'post-unification',
#  'sentinel',
#  'caldwell',
#  'farnum',
#  'boîte',
#  '23rd',
#  'answering',
#  'prado',
#  'cecília',
#  'criollo',
#  'kafkaesque',
#  'cauldron',
#  'build-up',
#  'illegittima',
#  'milan',
#  'vanny',
#  'quadroon',
#  'copter',
#  'goulekas',
#  'new-born',
#  'adige',
#  'miss-matched',
#  'banasur',
#  'garland',
#  'gospodin',
#  'f.b.i.',
#  'mirabelle',
#  'recession-plagued',
#  'relieve',
#  'marriageable',
#  'percelli',
#  'gregoric',
#  'women.the',
#  'einaudi',
#  'cereals',
#  'karaiskakio',
#  'charity-organisation',
#  'noncommittal',
#  'marzo',
#  'j-taime',
#  'incessantly',
#  'traditions',
#  'barber/manager.upon',
#  'decision-makers',
#  '378',
#  'evgeni',
#  'simultaneously',
#  'anzai',
#  'leukemia',
#  'timaeus',
#  'unimpressed',
#  'ezt',
#  'dorina',
#  'stubby',
#  'amputate',
#  'compassionately',
#  'déroule',
#  'crystals',
#  'eke',
#  'uppsala',
#  'middlesex',
#  'stroke.what',
#  'manik',
#  'urmila',
#  'arja',
#  'described',
#  'denby',
#  'commencement',
#  'builders',
#  'subprime',
#  'prejudice',
#  'magasin',
#  'pasts',
#  'poisoned',
#  'carriera',
#  "un'ultima",
#  'zufall',
#  'leica',
#  'volunteer',
#  'servitors',
#  'ever-danish',
#  '50-year',
#  'indifferently',
#  'dawin',
#  'suspects',
#  'unaffected',
#  'wi',
#  'vaqueros',
#  'compensating',
#  'balançoire',
#  'aleqa',
#  'erwtje',
#  'quickly-spreading',
#  'scontento',
#  'accolta',
#  'ender',
#  'commemorates',
#  'stepnicka',
#  'cossacks',
#  'boiler',
#  'boogaloo',
#  'link',
#  'seton',
#  'klostermann',
#  'droids',
#  'whole-hogger',
#  'fukui',
#  "'return",
#  'asylum-seekers',
#  'sadaawi',
#  'well-stocked',
#  'psp',
#  'milosovic',
#  'hanako-san',
#  'camarero',
#  'dhs',
#  'disputes',
#  'aryavardhan',
#  'yair',
#  'roehler',
#  'montréalers',
#  'hard-up',
#  'f-20',
#  "friends'name",
#  'panneer',
#  'paparazzi',
#  'bisogno',
#  'ellenson',
#  'patil',
#  'madding',
#  'ministered',
#  'decrepit',
#  'skeletons',
#  'gimpo',
#  'assailants',
#  'method',
#  'kidane',
#  'feignedly',
#  'physiotherapy',
#  "'brownist",
#  'belair',
#  'money-grubbing',
#  'lor',
#  'time-frame',
#  'reunited.pregnancy',
#  'hoopla',
#  'efratia',
#  'chenier',
#  'austerlitz',
#  'uremia',
#  'bombardments',
#  'jaywant',
#  'contraintes',
#  're-telling',
#  'redeems',
#  'ex-chef',
#  'leeová',
#  'imprisonments',
#  'kwang-pil',
#  'polini',
#  "'negative",
#  'echoes',
#  'marooned',
#  'goodie-bag',
#  'ormerod',
#  'hegemonic',
#  'peregrine',
#  'ganzá',
#  'coozan',
#  '1chthy5',
#  'feature-',
#  'vidic',
#  'anup',
#  'degrowth',
#  'skullgirl',
#  'toy-collecting',
#  'bodley',
#  'skinny-dipping',
#  'hate-sermon',
#  'glimmers',
#  'fosse',
#  'dacoit',
#  'verapas',
#  'incompassated',
#  '401s',
#  'devaluation',
#  'paoletta',
#  'yadav',
#  'parsčment',
#  'kagawa',
#  'herdis',
#  'notify',
#  'tasmin',
#  'járja',
#  'wantanbe',
#  'hygienically',
#  'lomeli',
#  'storytellers',
#  'kok',
#  'antionette',
#  'stackridge',
#  'dreamscapes',
#  'chaudaran',
#  'lassiter',
#  'astronaut',
#  'teeter',
#  '3:33',
#  'vanasse',
#  'vily',
#  'stully',
#  'deakids',
#  'edomite',
#  'fronts',
#  'fixture',
#  'zábrana',
#  'abuts',
#  'magnus',
#  'drug-using',
#  'milburn',
#  'hoberman',
#  'opryland',
#  'warrier',
#  'warrior-who',
#  'conservatories',
#  'staged',
#  'edited',
#  'tint',
#  'vangitsee',
#  'navigation',
#  'ozeanders',
#  'jhawhan',
#  'auto-mechanized',
#  'convenience-obsessed',
#  'protagonizadas',
#  'nimbus',
#  'smiggen',
#  'intrinsic',
#  'cheez-it',
#  'needs-and',
#  'chaude',
#  'student/teacher',
#  'ninon',
#  'mdladla',
#  'declination',
#  'petrila',
#  'podnieks',
#  'primus',
#  'stana',
#  'strugglesto',
#  '1975-1990',
#  'fetches',
#  'bentini',
#  'slinks',
#  'abhi',
#  'neri',
#  'rossland',
#  'areal',
#  'suo',
#  'joy',
#  'alce',
#  'stockholder',
#  'dung.everything',
#  'matyasovsky',
#  'flutterband',
#  'thomases',
#  'ava',
#  'electricity',
#  'cabardo',
#  'entirely',
#  'dipali',
#  'fille',
#  'apprende',
#  'messianic',
#  'limit',
#  'valparaiso',
#  'unconsciousness',
#  'raghunath.raghunath',
#  'tels',
#  'prototyped',
#  'topan',
#  'anicca',
#  'ukelele',
#  'botanist',
#  'kageyama',
#  'in-bred',
#  'xperiment',
#  'riaz',
#  'rachael',
#  'pauvre',
#  'clink',
#  'coherence',
#  'zuckmayer',
#  'punchy',
#  "'moulin-maudit",
#  'prohibition-era',
#  'siamese',
#  'siena',
#  'salazars',
#  'kramo',
#  'kord',
#  'lucienne',
#  'deepest-held',
#  'mont-royal',
#  'dreary',
#  'hearthstone',
#  'pelke',
#  '3,800',
#  'birthfather',
#  'anaesthetists',
#  'oral',
#  'gowri',
#  'show/sketch',
#  'catelina',
#  'fund-raiser',
#  'sobering',
#  'bane',
#  'close-and-personal',
#  'catta-preta',
#  'kort',
#  'kassandra',
#  'dwellers',
#  'cargoes',
#  'mmc',
#  '1752',
#  'ravaged',
#  'asceticism',
#  'bam',
#  'maghda',
#  'sloth',
#  'revati',
#  'andino',
#  'irle',
#  'tele-c',
#  'tipsily',
#  'take-over',
#  'shahi',
#  'potente',
#  'niche',
#  'documentay',
#  'dususu',
#  'slona',
#  'kadarkarai',
#  'lifeline',
#  'slumberg',
#  'ceremony',
#  'sazburg',
#  'snavely',
#  'rent',
#  'fly-rod',
#  'myshkin',
#  'aniruddha',
#  'superstore',
#  'creations',
#  'manned',
#  'fis',
#  'rootin',
#  'misprint',
#  'perceval',
#  'dealer/hustler/bookie',
#  'imperceptiblemente',
#  'vold',
#  'flag-bearers',
#  'yugoslavia',
#  'daffy',
#  'designate',
#  'doctorial',
#  'ayer',
#  'shizui',
#  'teure',
#  'mariama',
#  'beware-your',
#  'destitute',
#  'impaled',
#  'durant',
#  'svenandsophie',
#  'kuril',
#  'ballymurphy',
#  'challanges',
#  '2005.',
#  'empire',
#  'madurai',
#  'schooler',
#  'carnevale',
#  'flanders',
#  'director/screenwriter',
#  'bigamous',
#  '13-year-old',
#  'moans',
#  'conforms',
#  'influencers',
#  'fortyish',
#  'tallaght',
#  'malabar',
#  'blow',
#  'skjulte',
#  'aji',
#  'chiharu',
#  'seventeen-year',
#  'accented',
#  'mirror-like',
#  'westboro',
#  'narrate',
#  'pop-punk',
#  'chandramohan/date',
#  'hurston',
#  'nehezseget',
#  '3,260',
#  'powrs',
#  "ă'âşjica",
#  'srdjan',
#  'barking',
#  'shin-ho',
#  'flashbacks',
#  '.he',
#  'desecrating',
#  'dapl',
#  'modernity',
#  'jaiselmer',
#  'society.while',
#  'dunder',
#  'governance',
#  'crack-fueled',
#  "j'avais",
#  'harmadik',
#  'andrée',
#  'hortus',
#  'christoph',
#  '9-19',
#  'clogging',
#  'despising',
#  'canadian',
#  'indermohan',
#  'loristan',
#  'hollenbeck',
#  'entertainment',
#  'heung',
#  'iconography',
#  'jeeva',
#  'melike',
#  'salads',
#  'pieten',
#  'all-for-nots',
#  'popowka',
#  'delaghetto',
#  'dragos',
#  'saugrenues',
#  'flamingos',
#  'doyenne',
#  'terminally-ill',
#  'hangars',
#  'transporte',
#  'cohn',
#  'quarreling',
#  'agares',
#  '90-year-old',
#  'ratos',
#  'lavalle',
#  'masterpiece',
#  'biblical',
#  'greenhouse',
#  'ludicrous',
#  'merback',
#  "n'ai",
#  'iaa',
#  'napolitan',
#  'isreals',
#  'parvan',
#  'cards',
#  'retaliated',
#  'o-1',
#  'displacing',
#  'laredoans',
#  'explode',
#  'karpathios',
#  'j.b.',
#  'tajjab',
#  'compton.the',
#  'emotions-filled',
#  'huagou',
#  'songwriters',
#  'self-uncovering',
#  'rahab',
#  'post-college',
#  'stomach',
#  'busty',
#  'revamp',
#  'chiltern',
#  'produces',
#  'féodor',
#  'erste',
#  'edmonds',
#  'halligan',
#  'low-paying',
#  '1931',
#  'audley',
#  'ektemann',
#  'concert/event',
#  'huta',
#  'mercedita',
#  'trascorso',
#  'eingeschlossen',
#  'v4',
#  'musters',
#  'étrange',
#  'mileva',
#  'chandanpur',
#  'kittisak',
#  'valentine',
#  'juxtaposition',
#  'heir-apparent',
#  'cab',
#  'rushing',
#  'constitutes',
#  'souraya',
#  'mall-a-minute',
#  'non-lethal',
#  'dothan',
#  'mangiacake',
#  'tipis',
#  'vigile',
#  'ah',
#  '.father',
#  'subjugates',
#  'wouned',
#  'fire-spinning',
#  'gunwharf',
#  'hemp.her',
#  'chola',
#  'keszult',
#  'telefonata',
#  'venitia',
#  'u.s.president',
#  'asociacion',
#  'governmental',
#  'juice',
#  'streams-a',
#  'petersburg.on',
#  'mercenary-cum-vigilante',
#  'renderlo',
#  'anc',
#  'saddened',
#  "'line",
#  'fourge',
#  'voth',
#  'downcast',
#  'combine-painting',
#  'voice-mail',
#  'ghost-tracker',
#  '2,900-mile',
#  'bintou',
#  'imperturbably',
#  'rug-cuttin',
#  'childbirth',
#  'twin-bill',
#  'unconscious',
#  'skipsrederi',
#  'markéta',
#  'comedians',
#  'unease',
#  'czajkowska',
#  'playgrounds',
#  'co-incidentally',
#  'clamide',
#  'para-military',
#  'namaste',
#  'gampu',
#  'necrosearch',
#  'inflicts',
#  'fsm',
#  'posters',
#  'andreis',
#  'big-money',
#  'vede',
#  'gaming',
#  ...}

# %%
bow={word:index for index,word in enumerate(filter)}
bow
# Out:
# {'listening': 2608224,
#  'conversation': 2701454,
#  'doctor': 2709415,
#  'parents': 2709743,
#  '10-year-old': 2636331,
#  'oscar': 2605082,
#  'learns': 2706289,
#  'nobody': 2698483,
#  'courage': 2695418,
#  'tell': 2709817,
#  'weeks': 2708923,
#  'live': 2709798,
#  'furious': 2668479,
#  'refuses': 2707686,
#  'speak': 2706137,
#  'anyone': 2702846,
#  'except': 2699292,
#  'straight-talking': 2672591,
#  'rose': 2706797,
#  'lady': 2703828,
#  'pink': 2685689,
#  'meets': 2709536,
#  'hospital': 2708988,
#  'stairs': 2703579,
#  'christmas': 2702134,
#  'approaches': 2647095,
#  'uses': 2706598,
#  'fantastical': 2707008,
#  'experiences': 2705768,
#  'professional': 2706644,
#  'wrestler': 2701103,
#  'imagination': 2707343,
#  'wit': 2675719,
#  'charm': 2688845,
#  'allow': 2698058,
#  'life': 2709819,
#  'love': 2709639,
#  'full': 2708025,
#  'company': 2708912,
#  'friends': 2709298,
#  'pop': 2705676,
#  'corn': 2573547,
#  'einstein': 2675837,
#  'bacon': 2709400,
#  'childhood': 2707478,
#  'sweetheart': 2701715,
#  'peggy': 2598457,
#  'blue': 2705400,
#  'brother': 2705014,
#  'sister': 2704073,
#  'past': 2708471,
#  'incestuous': 2175370,
#  'relationship': 2708584,
#  'current': 2699129,
#  'murderous': 2687641,
#  'murders': 2706959,
#  'women': 2709154,
#  'reject': 2690331,
#  'get': 2709814,
#  'close': 2706491,
#  'help': 2707862,
#  'unemployed': 2708453,
#  'father': 2709325,
#  'make': 2709002,
#  'ends': 2709003,
#  'meet': 2709606,
#  'edith': 2706168,
#  'twin': 2707714,
#  'grace': 2708298,
#  'work': 2709835,
#  'seamstresses': 2027557,
#  'invalid': 2704260,
#  'falls': 2708111,
#  'prey': 2705549,
#  'temptations': 2669646,
#  'chinatown': 2700457,
#  'opium': 2700514,
#  'becomes': 2709848,
#  'addict': 2704613,
#  'condition': 2682781,
#  'worsened': 2213755,
#  'misguided': 2640367,
#  'physician': 2697085,
#  'prescribes': 2176608,
#  'morphine': 2302041,
#  'ease': 2511710,
#  'pain': 2672181,
#  'strikes': 2629796,
#  'oil': 2688012,
#  'family': 2709731,
#  'enjoys': 2644599,
#  'new': 2709428,
#  'prosperity': 2562541,
#  'sisters': 2709701,
#  'eligible': 2707737,
#  'jack': 2708792,
#  'herron': 106,
#  'fellow': 2698572,
#  'prospector': 2655057,
#  "'s": 2709774,
#  'shock': 2709728,
#  'jealousy': 2709618,
#  'tells': 2709583,
#  'drug': 2708210,
#  'problem': 2698920,
#  'hinting': 2557688,
#  'soon': 2709847,
#  'need': 2704739,
#  'arranges': 2672112,
#  'dinner': 2703593,
#  'couple': 2708333,
#  'dance': 2683636,
#  'slips': 2679655,
#  'away': 2707525,
#  'den': 2681696,
#  'follows': 2707492,
#  'wrong': 2708969,
#  'arrested': 2708258,
#  'ensuing': 2694651,
#  'raid': 2706438,
#  'bails': 2477458,
#  'jail': 2706460,
#  'takes': 2709486,
#  'angry': 2692479,
#  'search': 2707426,
#  'stumbles': 2703124,
#  'across': 2708881,
#  'half-conscious': 161,
#  'body': 2706928,
#  'lying': 2618192,
#  'street': 2691096,
#  'truth': 2702015,
#  'revealed': 2709273,
#  'sending': 2698643,
#  'sanitarium': 2575336,
#  'country': 2709799,
#  'married': 2709108,
#  'film': 2709767,
#  'title': 2708798,
#  'refers': 2664034,
#  'un-recovered': 179,
#  'bodies': 2709610,
#  'ground': 2683073,
#  'zero': 2662372,
#  'also': 2708006,
#  'state': 2709381,
#  'nation': 2706316,
#  'large': 2701644,
#  'set': 2708549,
#  'hallucinatory': 2416548,
#  'period': 2705038,
#  'time': 2709801,
#  'september': 2696972,
#  '11': 2695085,
#  'halloween': 2694004,
#  '2001': 2659942,
#  'unrecovered': 222,
#  'examines': 2696437,
#  'effect': 2701972,
#  'terror': 2698766,
#  'average': 2680068,
#  'mind': 2698300,
#  'way': 2709812,
#  'heightened': 2687000,
#  'anxiety': 2543921,
#  'and/or': 2681713,
#  'alertness': 206,
#  'cause': 2708303,
#  'person': 2707296,
#  'sort': 2703772,
#  'imaginative': 2598528,
#  'connections': 2673371,
#  'normally': 2695535,
#  'made': 2707919,
#  'artists': 2709135,
#  'conspiracy': 2707711,
#  'theorists-both': 218,
#  'figure': 2704119,
#  'prominently': 2597480,
#  'explores': 2701749,
#  'irony': 2708825,
#  'empathy': 2624492,
#  'paranoia': 2649733,
#  'relate': 2675959,
#  'one': 2709770,
#  'another': 2709110,
#  'wake': 2691721,
#  '9/11': 2680040,
#  'quality': 2700588,
#  'control': 2709636,
#  'consists': 2656325,
#  'series': 2707511,
#  '16mm': 2688136,
#  'single': 2708575,
#  'take': 2709823,
#  'shots': 2707231,
#  'filmed': 2709475,
#  'summer': 2694664,
#  '2010': 2704212,
#  'two': 2709744,
#  'day': 2709218,
#  'dry': 2681223,
#  'cleaners': 2567552,
#  'facility': 2709190,
#  'pritchard': 2027675,
#  'alabama': 2670814,
#  'near': 2709214,
#  'mobile': 2699545,
#  'exhibits': 2641832,
#  'acts': 2704430,
#  'well': 2708951,
#  'conditions': 2704338,
#  'around': 2709645,
#  'labor': 2706391,
#  'showcases': 2694136,
#  'everson': 1897541,
#  'words': 2701326,
#  '``': 2709396,
#  'fine': 2706378,
#  'folks': 2682912,
#  'producing': 2688260,
#  'superior': 2673217,
#  'product': 2666223,
#  "''": 2709403,
#  'similar': 2704625,
#  'stylistically': 1886158,
#  'form': 2693977,
#  'rhythm': 2702749,
#  'certain': 2706114,
#  'scenarios': 2650814,
#  'award-winning': 2709579,
#  'critically': 2694369,
#  'acclaimed': 2635751,
#  'previous': 2702083,
#  'films': 2691660,
#  'including': 2705592,
#  'erie': 2298653,
#  'iffr': 370,
#  'thematic': 2586840,
#  'concerns': 2692503,
#  'several': 2708208,
#  'short': 2708144,
#  'works': 2704758,
#  'follow': 2709280,
#  'daily': 2707959,
#  'quotidian': 2359941,
#  'tasks': 2696737,
#  'workers': 2706385,
#  'rest': 2708484,
#  'motion': 2686474,
#  'oblique': 2441629,
#  'sequel': 2686459,
#  'ten': 2708436,
#  'years': 2709562,
#  'hence': 2629179,
#  'creative': 2698139,
#  'capital': 2709382,
#  'granted': 2651431,
#  'project': 2705530,
#  'week': 2708276,
#  'hole': 2674654,
#  'focused': 2695927,
#  'employee': 2688365,
#  'adjustment': 2207218,
#  'materials': 2659396,
#  'space': 2705762,
#  'personnel': 2656053,
#  'factory': 2693437,
#  'routine': 2702449,
#  'captured': 2702951,
#  'principal': 2673761,
#  'cast': 2707287,
#  'includes': 2705350,
#  'shay': 1664439,
#  'wright': 2674958,
#  'annette': 2576704,
#  'speight': 408,
#  'tough': 2702874,
#  'economic': 2699130,
#  'times': 2706371,
#  'max': 2707398,
#  'joey': 2703556,
#  'run': 2709351,
#  'ideas': 2699219,
#  'discover': 2706819,
#  'senior': 2691386,
#  'housing': 2699622,
#  'cheap': 2691482,
#  'aunt': 2704835,
#  'kicked': 2701658,
#  'bucket': 2441519,
#  'knows': 2707521,
#  'yet': 2709634,
#  'hilarious': 2703922,
#  'always': 2705760,
#  'keeps': 2682602,
#  'toes': 2651665,
#  'us': 2707263,
#  'cross-dressing': 2686664,
#  'desperate': 2704364,
#  'endearing': 2597039,
#  'ride': 2704500,
#  'broke': 2678748,
#  'four': 2709059,
#  'high': 2709293,
#  'school': 2709294,
#  'students': 2705706,
#  'embark': 2704515,
#  'terrifying': 2706155,
#  'journey': 2709188,
#  'shadowview': 470,
#  'manor': 2686516,
#  '2': 2708173,
#  'horrifying': 2699029,
#  'séance': 2153702,
#  'gone': 2706710,
#  'intern': 2685478,
#  'raven': 2503134,
#  'decides': 2709350,
#  'reconnect': 2706021,
#  'elementary': 2656728,
#  'kota': 1597829,
#  'william': 2705370,
#  'jessica': 2698526,
#  'bringing': 2708673,
#  'workplace': 2601265,
#  'bit': 2704772,
#  'paranormal': 2701014,
#  'investigating': 2694793,
#  'hearing': 2696301,
#  'forbidden': 2678275,
#  'secrets': 2706820,
#  'night': 2709231,
#  'janitor': 2684026,
#  'sends': 2709840,
#  'dark': 2705932,
#  'descending': 2460708,
#  'spiral': 2690369,
#  'tom': 2704445,
#  'beacham': 486,
#  'ghana': 2542234,
#  'director': 2708650,
#  'photography': 2697872,
#  'alex': 2709225,
#  'holberton': 492,
#  'spirits': 2700860,
#  'looks': 2707294,
#  'overlap': 2416278,
#  'spirit': 2705487,
#  'world': 2709171,
#  'physical': 2709069,
#  'voodoo': 2683164,
#  'witchcraft': 2586401,
#  'power': 2706612,
#  'holy': 2705486,
#  'magic': 2707299,
#  'royal': 2705852,
#  'members': 2704408,
#  'magicians': 2569797,
#  'priests': 2652001,
#  'getting': 2708568,
#  'rare': 2702337,
#  'footage': 2709150,
#  'ceremony': 2676666,
#  'danny': 2706006,
#  'dying': 2707128,
#  'aids': 2647457,
#  'returns': 2709332,
#  'home': 2709333,
#  'last': 2709552,
#  'months': 2709672,
#  'mother': 2709219,
#  'share': 2708231,
#  'moments': 2701221,
#  'openness': 2617128,
#  'tend': 2592687,
#  'shut': 2709364,
#  'breast': 2704622,
#  'cancer': 2704623,
#  'diagnosis': 2677534,
#  'action': 2702017,
#  'highlighting': 2671461,
#  'events': 2709513,
#  'took': 2707211,
#  'place': 2709624,
#  'franke': 2553704,
#  'participation': 2688747,
#  'susan': 2709850,
#  'g.': 2590617,
#  'komen': 1712093,
#  '3-day': 1828830,
#  'walk': 2661356,
#  'training': 2693958,
#  'fund-raising': 2503645,
#  'six': 2695700,
#  'preceding': 2512188,
#  'numerous': 2706809,
#  'interviews': 2708179,
#  'survivors': 2697407,
#  'wealth': 2685965,
#  'experience': 2703702,
#  'viewer': 2708822,
#  'included': 2695690,
#  'appearances': 2703973,
#  'local': 2709356,
#  'celebrities': 2706939,
#  'athletes': 2669845,
#  'musical': 2708185,
#  'informative': 2705520,
#  'health': 2707033,
#  'care': 2709658,
#  'professionals': 2705460,
#  'explain': 2690787,
#  'should': 2706626,
#  'know': 2707856,
#  'dealing': 2708967,
#  'illness': 2698327,
#  'given': 2699838,
#  'left': 2708733,
#  'office': 2705237,
#  'fateful': 2667600,
#  '...': 2709435,
#  'would': 2709311,
#  'remember': 2700817,
#  'alone': 2709228,
#  'photographer': 2706933,
#  'sailing': 2699575,
#  'wife': 2709824,
#  'nympho-maniacal': 624,
#  'model': 2707886,
#  'leaves': 2709655,
#  'three': 2709041,
#  'part': 2708507,
#  'boat': 2706479,
#  'mysterious': 2708648,
#  'man': 2709626,
#  'shows': 2709105,
#  'might': 2708000,
#  'escaped': 2708977,
#  'criminal': 2691083,
#  'police': 2706340,
#  'searching': 2698101,
#  "n't": 2709763,
#  'alarm': 2703318,
#  'much': 2709769,
#  'rapidly': 2697967,
#  'seduces': 2691846,
#  'amanda': 2617610,
#  'wingfield': 650,
#  'dominates': 2478113,
#  'children': 2709660,
#  'faded': 2652165,
#  'gentility': 893862,
#  'exaggerated': 2428288,
#  'tales': 2688231,
#  'southern': 2702352,
#  'belle': 2642903,
#  'son': 2708015,
#  'plans': 2709006,
#  'escape': 2709726,
#  'daughter': 2709753,
#  'withdraws': 2573437,
#  'dream': 2709289,
#  'gentleman': 2535260,
#  'caller': 2606475,
#  'appears': 2708634,
#  'things': 2709789,
#  'move': 2702118,
#  'crisis': 2706945,
#  'point': 2707279,
#  'faced': 2703367,
#  'dilemma': 2707902,
#  'dependent': 2595656,
#  'remaining': 2705959,
#  'importantly': 2668774,
#  'laura': 2685145,
#  'struggles': 2705029,
#  'use': 2709449,
#  'means': 2705834,
#  'disposable': 2561033,
#  'secure': 2697818,
#  'future': 2708474,
#  'frightened': 2616447,
#  'fragile': 2706855,
#  'spinster': 2649962,
#  'simon': 2705623,
#  'turned': 2696721,
#  'upside': 2696722,
#  'little': 2704282,
#  'girl': 2709186,
#  'katie': 2692620,
#  'abducted': 2709709,
#  'appeals': 2693200,
#  'punish': 2704182,
#  'offering': 2698610,
#  'young': 2709755,
#  'prostitute': 2704460,
#  'mounting': 2689936,
#  'debts': 2697801,
#  'changing': 2708492,
#  'money': 2709235,
#  'end': 2708304,
#  'frankie': 2705595,
#  'reno': 2698527,
#  'child': 2707751,
#  'star': 2707471,
#  'tv': 2709577,
#  'show': 2709673,
#  'thirty': 2707616,
#  'ago': 2708438,
#  'busy': 2704567,
#  'making': 2705418,
#  'running': 2709375,
#  'babylon': 2642867,
#  'vista': 2450627,
#  'hollywood': 2708279,
#  'apartment': 2706561,
#  'inhabited': 2668407,
#  'has-beens': 580020,
#  'wannabees': 2546070,
#  'stories': 2707285,
#  'rent': 2691251,
#  'payments': 2680109,
#  'slowly': 2707061,
#  'finds': 2709305,
#  'sucked': 2414299,
#  'bizarre': 2706127,
#  'dysfunctional': 2672176,
#  'tenants': 2642716,
#  'story': 2709584,
#  'castle': 2705493,
#  'norbert': 1476210,
#  'salburg-falkenstein': 767,
#  'commander': 2628579,
#  'knights': 2678854,
#  'malte': 213811,
#  'österreich': 796,
#  'bohemia': 2396703,
#  'naval': 2487681,
#  'sweden': 2660059,
#  'able': 2709481,
#  'restore': 2701845,
#  'property': 2705437,
#  'correctly': 2517297,
#  'wagnerian': 789,
#  'opera': 2709691,
#  'singer': 2709692,
#  'sings': 2687158,
#  'welsh': 2653644,
#  'music': 2709301,
#  'video': 2706274,
#  'nobility': 2488795,
#  'deutschland': 1997284,
#  'various': 2709063,
#  'castles': 2559215,
#  'lively': 2707885,
#  'fun': 2702621,
#  'commentary': 2708218,
#  'hosts': 2704425,
#  'descendant': 2563842,
#  'great': 2709549,
#  'hapsburg': 808,
#  'dynasty': 2689253,
#  'road': 2708257,
#  'milk': 2667549,
#  'narrates': 2708141,
#  'existential': 2693568,
#  'drama': 2708417,
#  'tones': 2618045,
#  'lost': 2707871,
#  'traveling': 2694667,
#  'roads': 2702128,
#  'brazil': 2704839,
#  'countryside': 2674161,
#  'back': 2709677,
#  'homeland': 2702311,
#  'find': 2709854,
#  'sign': 2670165,
#  'remake': 2706792,
#  'path': 2705619,
#  'salvation': 2697327,
#  'threshold': 2675558,
#  'reason': 2698361,
#  'madness': 2703957,
#  'death': 2709661,
#  'gang': 2707644,
#  'itinerant': 2535195,
#  'musicians': 2705660,
#  'play': 2709845,
#  'south': 2705331,
#  'stockholm': 2668370,
#  'chance': 2709688,
#  'orchestra': 2654988,
#  'restaurant': 2705937,
#  'goes': 2709015,
#  'female': 2707029,
#  'owner': 2703888,
#  'committee': 2705187,
#  'first': 2709630,
#  'uncensored': 2610961,
#  'network': 2705983,
#  'typical': 2707743,
#  'programming': 2483770,
#  'commercials': 2699237,
#  'news': 2708553,
#  'programs': 2696443,
#  'name': 2707938,
#  'surely': 2678462,
#  'crack': 2677391,
#  'outrageous': 2677626,
#  'irreverent': 2642297,
#  'spoof': 2642178,
#  'television': 2705647,
#  'launched': 2615352,
#  'careers': 2665269,
#  'greatest': 2709161,
#  'comedians': 2703971,
#  '1976': 2532228,
#  'tries': 2709508,
#  'predict': 2706728,
#  'american': 2707076,
#  'like': 2709617,
#  'year': 2708449,
#  '1985': 2610733,
#  'tunnelvision': 942,
#  'america': 2707931,
#  'free': 2700435,
#  'although': 2704901,
#  'wildly': 2703413,
#  'popular': 2709295,
#  'blamed': 2691504,
#  'increased': 2693759,
#  'crime': 2706324,
#  'unemployment': 2697179,
#  'christian': 2703558,
#  'a.': 2694923,
#  'broder': 1956227,
#  'president': 2706529,
#  'founder': 2705900,
#  'called': 2708704,
#  'defend': 2685883,
#  'front': 2701929,
#  'senate': 2673483,
#  'sub-committee': 934,
#  'view': 2708893,
#  'excerpts': 2654995,
#  'broadcasting': 2577773,
#  'brief': 2701349,
#  'skits': 2657165,
#  'lampooning': 948,
#  'cop': 2706363,
#  'broadcasts': 2613230,
#  'situation': 2708901,
#  'comedies': 2605020,
#  'course': 2702074,
#  'wedded': 2356683,
#  'bliss': 2647122,
#  'perception': 2643754,
#  'wedding': 2693467,
#  'newly': 2676967,
#  'perfect': 2705297,
#  'romantic': 2708778,
#  'reality': 2709102,
#  'many': 2709031,
#  'people': 2709794,
#  'families': 2709155,
#  'coming': 2706789,
#  'together': 2707909,
#  'almost': 2707615,
#  'miscommunication': 2026180,
#  'start': 2709632,
#  'small': 2709376,
#  'become': 2709290,
#  'bigger': 2707673,
#  'baggage': 2672128,
#  'big': 2709307,
#  'distraction': 2673496,
#  'struggle': 2700682,
#  'adapt': 2654635,
#  'drawn': 2701197,
#  'apart': 2706302,
#  'go': 2708848,
#  'process': 2709468,
#  'dong-woo': 1010,
#  'released': 2708168,
#  'prison': 2709182,
#  'following': 2709611,
#  'failed': 2708563,
#  'attempt': 2708522,
#  'rob': 2708250,
#  'watch': 2709790,
#  'shop': 2704769,
#  'footsteps': 2688220,
#  'popularity': 2627145,
#  'eclipses': 2229078,
#  'however': 2709532,
#  'leading': 2708581,
#  'unexpected': 2704824,
#  'problems': 2709750,
#  'brian': 2706000,
#  'wallace': 2694901,
#  'cameraman': 2677589,
#  'hit': 2704057,
#  "'riding": 1045,
#  'shotgun': 2553606,
#  'minute': 2707006,
#  'hauling': 2336843,
#  'ass': 2527562,
#  'alley': 2659742,
#  'trying': 2709822,
#  'keep': 2709836,
#  'cops': 2706407,
#  'chasing': 2707837,
#  'turn': 2708924,
#  'got': 2709687,
#  'separated': 2686799,
#  'damn': 2635171,
#  'knife': 2694753,
#  'throat': 2690016,
#  'face': 2708505,
#  'notorious': 2701883,
#  'leader': 2707519,
#  'named': 2704557,
#  'rolling': 2602329,
#  'irresistibly': 2671191,
#  'caught': 2708917,
#  'solidify': 572258,
#  'permanent': 2701601,
#  'truce': 2606280,
#  'enemy': 2695678,
#  'opportunity': 2706992,
#  'destroyed': 2707864,
#  'blind': 2700867,
#  'marie': 2690176,
#  'insecure': 2707022,
#  'housewife': 2701861,
#  'whose': 2709047,
#  'husband': 2708455,
#  'joe': 2706995,
#  'affair': 2709640,
#  'holiday': 2699745,
#  'rural': 2708790,
#  'scotland': 2707337,
#  'sheer': 2683466,
#  'bad': 2706347,
#  'luck': 2706225,
#  'hotel': 2708683,
#  'getaways': 750206,
#  'told': 2707049,
#  'boy': 2709369,
#  'drowned': 2437358,
#  'nearby': 2705118,
#  'lake': 2702022,
#  'long': 2709484,
#  'becoming': 2699439,
#  'obsessed': 2706940,
#  'ghost': 2704363,
#  'upper-middle': 2326530,
#  'class': 2703795,
#  'background': 2706266,
#  'good': 2709367,
#  'education': 2704653,
#  'adolescent': 2656211,
#  '37': 2396535,
#  'old': 2708450,
#  'canadian': 2696081,
#  'lisa': 2669428,
#  'seemed': 2701472,
#  'least': 2702861,
#  'likely': 2690885,
#  'dangerous': 2709196,
#  'self-destructive': 2650413,
#  'addiction': 2681434,
#  'prostitution': 2687947,
#  'funds': 2622809,
#  'habit': 2693040,
#  'discusses': 2690797,
#  'honest': 2696473,
#  'open': 2708928,
#  'articulate': 2586674,
#  'manner': 2691391,
#  'intimate': 2698612,
#  'setting': 2685016,
#  'toronto': 2690876,
#  'room': 2707047,
#  'precise': 2585343,
#  'led': 2707785,
#  'tragic': 2697495,
#  'currently': 2707971,
#  'ultimately': 2708526,
#  'wants': 2709034,
#  'nothing': 2706563,
#  'reach': 2708328,
#  'sobriety': 2254706,
#  'someday': 2333780,
#  'return': 2705158,
#  'semblance': 2700128,
#  'normal': 2700129,
#  'friend': 2707632,
#  'hopefully': 2661616,
#  'educate': 2640752,
#  'others': 2709238,
#  'specifically': 2694129,
#  'found': 2708641,
#  'since': 2706204,
#  'vampires': 2606304,
#  'underworld': 2706519,
#  'creatures': 2672747,
#  'used': 2709145,
#  'industry': 2706417,
#  'fashion': 2699339,
#  'lore': 2550602,
#  'protecting': 2701007,
#  'human': 2709573,
#  'society': 2708818,
#  'detective': 2709807,
#  'peter': 2707254,
#  'king': 2699969,
#  'involved': 2706059,
#  'personally': 2633299,
#  'professionally': 2590320,
#  'osvanna': 1243,
#  'moore': 2701281,
#  'scream': 2633769,
#  'queen': 2709091,
#  'horror': 2709775,
#  'studio': 2694143,
#  'mogul': 2645373,
#  '400': 2696347,
#  'vampire': 2688732,
#  'try': 2709001,
#  'outpace': 1239,
#  'serial': 2704384,
#  'killer': 2706709,
#  'targeted': 2632464,
#  'clan': 2660914,
#  'objective': 2706119,
#  'documentary': 2709580,
#  'convey': 2694657,
#  'exciting': 2706741,
#  'alberto': 2706780,
#  'corazón': 1970534,
#  'career': 2707488,
#  'contribution': 2701385,
#  'spanish': 2705509,
#  'culture': 2700770,
#  'personality': 2709053,
#  'character': 2706893,
#  'especially': 2697654,
#  'visual': 2707249,
#  'recognition': 2705641,
#  'marks': 2675503,
#  'symbols': 2680660,
#  'corporate': 2708561,
#  'identities': 2674233,
#  'industrial': 2706146,
#  'designs': 2590392,
#  'objects': 2705147,
#  'signs': 2702476,
#  'showing': 2706100,
#  'closely': 2681021,
#  'transparently': 1286,
#  'create': 2702265,
#  'trajectory': 2600257,
#  'linked': 2708679,
#  'recent': 2709561,
#  'history': 2708682,
#  'spain': 2705507,
#  'broadest': 804319,
#  'sense': 2708623,
#  'editorial': 2608851,
#  'design': 2708498,
#  'posters': 2606598,
#  'wall': 2693285,
#  'paintings': 2708791,
#  'sundials': 1302,
#  'sculptures': 2498049,
#  'books': 2705864,
#  'respecting': 2656374,
#  'intimacy': 2709237,
#  'thai': 2706393,
#  'town': 2709380,
#  'six-block': 1315,
#  'area': 2706472,
#  'los': 2701398,
#  'angeles': 2701399,
#  '50,000': 2708316,
#  'expatriated': 2150104,
#  'thais': 2685359,
#  'gateway': 2678696,
#  'entering': 2639139,
#  'dubbed': 2668382,
#  'thailand': 2699824,
#  '77th': 1333,
#  'province': 2691292,
#  'movie': 2707681,
#  'survive': 2704170,
#  'fast-paced': 2648998,
#  'consumerist': 2606681,
#  'still': 2707984,
#  'maintaining': 2663620,
#  'traditional': 2700724,
#  'values': 2709642,
#  'identity': 2705219,
#  'thai-ness': 1352,
#  'octane': 2232143,
#  'west': 2702832,
#  'coast': 2702502,
#  'defined': 2661975,
#  'hip-hop': 2704450,
#  'drugs': 2703744,
#  'racing': 2708479,
#  'violence': 2700814,
#  'affects': 2663775,
#  'pat': 2701772,
#  'tempted': 2610086,
#  'hundred': 2694683,
#  'twenty': 2708268,
#  'nine': 2664284,
#  'episodes': 2709092,
#  'syndicated': 2696969,
#  'produced': 2703752,
#  '1973': 2647929,
#  '1978': 2662209,
#  'debuted': 2591901,
#  'usa': 2680368,
#  'fall': 2705231,
#  'wildlife': 2687225,
#  'whether': 2703641,
#  'blocking': 2656461,
#  'mouse': 2627655,
#  'holes': 2701052,
#  'landlords': 2422315,
#  'puppet': 2614136,
#  'bath': 2679942,
#  'never': 2709737,
#  'dull': 2680869,
#  'moment': 2703727,
#  'break': 2708427,
#  'online': 2705827,
#  'terrors': 2392438,
#  'temping': 1415,
#  'natalie': 2658879,
#  'presents': 2709418,
#  'lives': 2709359,
#  'housemates': 2618407,
#  'struggling': 2707515,
#  'ladder': 2614414,
#  'uni': 2246938,
#  'pay': 2700587,
#  'helped': 2700512,
#  'along': 2708012,
#  'keara': 1431,
#  "'real": 2699571,
#  'job': 2708984,
#  'jos': 2607527,
#  'wakes': 2689007,
#  'homeless': 2704791,
#  'shelter': 2702131,
#  'groningen': 1704464,
#  'north': 2705305,
#  'netherlands': 2679321,
#  'stay': 2705196,
#  '10am': 1446,
#  'starts': 2707791,
#  'come': 2709676,
#  'rain': 2669878,
#  'shine': 2651824,
#  'matter': 2709320,
#  "'re": 2703599,
#  'ill': 2701840,
#  'feel': 2707991,
#  'leaving': 2706433,
#  '10pm': 1461,
#  'welcome': 2679049,
#  'today': 2709773,
#  'different': 2709060,
#  'plan': 2708939,
#  'amends': 2649825,
#  'convince': 2709675,
#  'ex': 2709537,
#  'girlfriend': 2709036,
#  'going': 2709791,
#  'change': 2707648,
#  'drinking': 2702619,
#  'coke': 2677242,
#  'heroin': 2667529,
#  'junk': 2688404,
#  'maybe': 2704115,
#  'really': 2709541,
#  'starting': 2709285,
#  '......': 2673502,
#  'tomorrow': 2658270,
#  'tempest': 2619706,
#  'house': 2709705,
#  'narcés': 1508,
#  'arose': 2497841,
#  'martín': 2021082,
#  'angélica': 31963,
#  'mysteriously': 2709706,
#  ...}

# %%
df
# Out:
#                                              Title          Genre
# 0                    Oscar et la dame rose (2009)          drama   \
# 1                                    Cupid (1997)       thriller
# 3                           The Secret Sin (1915)          drama
# 4                          The Unrecovered (2007)          drama
# 5                          Quality Control (2011)    documentary
# ...                                            ...            ...
# 54207                              Kaçamak (1988)          drama
# 54209                             "Bonino" (1953)         comedy
# 54210                 Dead Girls Don't Cry (????)         horror
# 54211   Ronald Goedemondt: Ze bestaan echt (2008)    documentary
# 54212                    Make Your Own Bed (1944)         comedy
#
#                                              Description
# 0       Listening in to a conversation between his do...
# 1       A brother and sister with a past incestuous r...
# 3       To help their unemployed father make ends mee...
# 4       The film's title refers not only to the un-re...
# 5       Quality Control consists of a series of 16mm ...
# ...                                                  ...
# 54207   A man and woman meet during the identificatio...
# 54209   This short-lived NBC live sitcom centered on ...
# 54210   The NEXT Generation of EXPLOITATION. The sist...
# 54211   Ze bestaan echt, is a stand-up comedy about g...
# 54212   Walter and Vivian live in the country and hav...
#
# [45371 rows x 3 columns]

# %%
x=df['Description']
y=df['Genre']

# %%
x
# Out:
# 0         Listening in to a conversation between his do...
# 1         A brother and sister with a past incestuous r...
# 3         To help their unemployed father make ends mee...
# 4         The film's title refers not only to the un-re...
# 5         Quality Control consists of a series of 16mm ...
#                                ...
# 54207     A man and woman meet during the identificatio...
# 54209     This short-lived NBC live sitcom centered on ...
# 54210     The NEXT Generation of EXPLOITATION. The sist...
# 54211     Ze bestaan echt, is a stand-up comedy about g...
# 54212     Walter and Vivian live in the country and hav...
# Name: Description, Length: 45371, dtype: object

# %%
y
# Out:
# 0               drama
# 1            thriller
# 3               drama
# 4               drama
# 5         documentary
#              ...
# 54207           drama
# 54209          comedy
# 54210          horror
# 54211     documentary
# 54212          comedy
# Name: Genre, Length: 45371, dtype: object

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=10)

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import TfidfTransformer

# %%
count_vectorizer=CountVectorizer()
tfidf_vectorizer=TfidfVectorizer()

x_train_count=count_vectorizer.fit_transform(x_train)
x_train_tfidf=tfidf_vectorizer.fit_transform(x_train)

x_test_count=count_vectorizer.fit_transform(x_test)
x_test_tfidf=tfidf_vectorizer.fit_transform(x_test)

# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer

# Initialize vectorizers
count_vectorizer = CountVectorizer()
tfidf_vectorizer = TfidfVectorizer()

# Fit and transform on the training data
x_train_count = count_vectorizer.fit_transform(x_train)
x_train_tfidf = tfidf_vectorizer.fit_transform(x_train)

# Transform the test data
x_test_count = count_vectorizer.transform(x_test)
x_test_tfidf = tfidf_vectorizer.transform(x_test)

# %% [markdown]
# # MODEL 1: NAIVE-BAYES

# %%
from sklearn.naive_bayes import MultinomialNB

model = MultinomialNB()

model.fit(x_train_tfidf, y_train)
# Out:
# MultinomialNB()

# %%
predictions = model.predict(x_test_tfidf)


from sklearn.metrics import accuracy_score, classification_report

accuracy = accuracy_score(y_test, predictions)
report = classification_report(y_test, predictions)
print("accuracy :",accuracy)
print(report)
# Out:
# accuracy : 0.5367493112947659
#                precision    recall  f1-score   support
#
#       action        0.00      0.00      0.00       257
#       comedy        0.71      0.03      0.06      1418
#  documentary        0.68      0.89      0.77      2705
#        drama        0.44      0.89      0.59      2713
#       horror        0.00      0.00      0.00       417
#        short        1.00      0.00      0.00      1026
#     thriller        0.00      0.00      0.00       352
#      western        0.00      0.00      0.00       187
#
#      accuracy                           0.54      9075
#     macro avg       0.35      0.23      0.18      9075
#  weighted avg       0.56      0.54      0.42      9075
# C:\Users\Lenovo\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Lenovo\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Lenovo\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# # MODEL 2: LOGISTIC-REGRESSION

# %%
from sklearn.linear_model import LogisticRegression

model = LogisticRegression()

model.fit(x_train_tfidf, y_train)
# Out:
# C:\Users\Lenovo\AppData\Roaming\Python\Python311\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
predictions = model.predict(x_test_tfidf)


from sklearn.metrics import accuracy_score, classification_report

accuracy = accuracy_score(y_test, predictions)
report = classification_report(y_test, predictions)
print("accuracy :",accuracy)
print(report)
# Out:
# accuracy : 0.6865013774104683
#                precision    recall  f1-score   support
#
#       action        0.74      0.23      0.35       257
#       comedy        0.64      0.62      0.63      1418
#  documentary        0.77      0.89      0.83      2705
#        drama        0.63      0.80      0.70      2713
#       horror        0.78      0.58      0.66       417
#        short        0.59      0.28      0.38      1026
#     thriller        0.52      0.09      0.16       352
#      western        0.96      0.70      0.81       187
#
#      accuracy                           0.69      9075
#     macro avg       0.70      0.53      0.57      9075
#  weighted avg       0.68      0.69      0.66      9075

# %% [markdown]
# # MODEL 3 : SUPPORT-VECTOR-CLASSIFIER

# %%
from sklearn.svm import SVC

model = SVC(kernel='rbf',C=1,gamma='auto',decision_function_shape='ovr')

model.fit(x_train_tfidf, y_train)

# %%
predictions = model.predict(x_test_tfidf)


from sklearn.metrics import accuracy_score, classification_report

accuracy = accuracy_score(y_test, predictions)
report = classification_report(y_test, predictions)
print("accuracy",accuracy)
print(report)
